# %% [markdown]
# # Entranamiento de modelos con cleaned text y lematización

# %%
import pandas as pd

# Cargar los conjuntos de entrenamiento y desarrollo
train_df = pd.read_csv("../data/TA1C_dataset_detection_train_split.csv")
dev_df = pd.read_csv("../data/TA1C_dataset_detection_dev_split.csv")

# Verificar las columnas disponibles
print(train_df.columns)
# Out:
# Index(['Tweet ID', 'Teaser Text', 'Tag Value', 'tokenized_text',
#        'cleaned_text', 'no_stopwords_text', 'lemmatized_text',
#        'tokenized_cleaned_text', 'tokenized_cleaned_text_no_stopwords',
#        'tokenized_cleaned_text_no_stopwords_lemmatized',
#        'cleaned_lemmatized_text'],
#       dtype='object')

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Probar diferentes configuraciones de n-gramas y representaciones
configurations = [
    {"ngram_range": (1, 1), "representation": "tfidf"},  # Unigramas con TF-IDF
    {"ngram_range": (1, 2), "representation": "tfidf"},  # Unigramas + Bigramas con TF-IDF
    {"ngram_range": (1, 3), "representation": "tfidf"},  # Unigramas + Bigramas + Trigramas con TF-IDF
    {"ngram_range": (1, 2), "representation": "binary"},  # Unigramas + Bigramas con representación binaria
    {"ngram_range": (1, 2), "representation": "frequency"},  # Unigramas + Bigramas con frecuencia
]

for config in configurations:
    print(f"Configuración: ngram_range={config['ngram_range']}, representación={config['representation']}")
    
    # Configurar el vectorizador
    if config["representation"] == "tfidf":
        vectorizer = TfidfVectorizer(ngram_range=config["ngram_range"])
    elif config["representation"] == "binary":
        vectorizer = TfidfVectorizer(ngram_range=config["ngram_range"], binary=True)
    elif config["representation"] == "frequency":
        vectorizer = TfidfVectorizer(ngram_range=config["ngram_range"], use_idf=False)
    
    # Crear representaciones para el conjunto de entrenamiento y desarrollo
    X_train = vectorizer.fit_transform(train_df['cleaned_lemmatized_text'])
    X_dev = vectorizer.transform(dev_df['cleaned_lemmatized_text'])
    
    # Verificar las dimensiones
    print(f"Dimensiones de X_train: {X_train.shape}")
    print(f"Dimensiones de X_dev: {X_dev.shape}")
# Out:
# Configuración: ngram_range=(1, 1), representación=tfidf
# Dimensiones de X_train: (2100, 8843)
# Dimensiones de X_dev: (700, 8843)
# Configuración: ngram_range=(1, 2), representación=tfidf
# Dimensiones de X_train: (2100, 38037)
# Dimensiones de X_dev: (700, 38037)
# Configuración: ngram_range=(1, 3), representación=tfidf
# Dimensiones de X_train: (2100, 76866)
# Dimensiones de X_dev: (700, 76866)
# Configuración: ngram_range=(1, 2), representación=binary
# Dimensiones de X_train: (2100, 38037)
# Dimensiones de X_dev: (700, 38037)
# Configuración: ngram_range=(1, 2), representación=frequency
# Dimensiones de X_train: (2100, 38037)
# Dimensiones de X_dev: (700, 38037)

# %%
from sklearn.decomposition import TruncatedSVD

# Reducir dimensionalidad con TruncatedSVD
svd = TruncatedSVD(n_components=100, random_state=0)  # Reducir a 100 dimensiones
X_train_reduced = svd.fit_transform(X_train)
X_dev_reduced = svd.transform(X_dev)

# Verificar las dimensiones después de la reducción
print(f"Dimensiones reducidas de X_train: {X_train_reduced.shape}")
print(f"Dimensiones reducidas de X_dev: {X_dev_reduced.shape}")
# Out:
# Dimensiones reducidas de X_train: (2100, 100)
# Dimensiones reducidas de X_dev: (700, 100)

# %%
# Convertir etiquetas de texto a valores numéricos
label_mapping = {'Clickbait': 1, 'No': 0}
train_df['Tag Value'] = train_df['Tag Value'].map(label_mapping)
dev_df['Tag Value'] = dev_df['Tag Value'].map(label_mapping)

# %% [markdown]
# ## Logistic Regression y Validación Cruzada

# %%
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import make_scorer, f1_score

# Configurar validación cruzada estratificada
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)

# Definir el modelo
model = LogisticRegression(max_iter=200)

# Evaluar el modelo con validación cruzada usando f1_macro
f1_macro_scorer = make_scorer(f1_score, average='macro')
scores = cross_val_score(model, X_train_reduced, train_df['Tag Value'], cv=cv, scoring=f1_macro_scorer)

# Imprimir los resultados
print(f"F1-macro scores por fold: {scores}")
print(f"F1-macro promedio: {scores.mean():.4f}")
# Out:
# F1-macro scores por fold: [0.60034218 0.57072687 0.62629208 0.59183673 0.5646507 ]
# F1-macro promedio: 0.5908

# %% [markdown]
# ## Naive Bayes Multinominal

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import cross_val_score

# Definir el modelo de Naïve Bayes Multinomial
nb_model = MultinomialNB()

# Evaluar el modelo con validación cruzada usando las representaciones originales (X_train)
nb_scores = cross_val_score(nb_model, X_train, train_df['Tag Value'], cv=5, scoring='f1_macro')

# Imprimir los resultados
print("Naïve Bayes Multinomial (sin TruncatedSVD):")
print(f"F1-macro scores por fold: {nb_scores}")
print(f"F1-macro promedio: {nb_scores.mean():.4f}")
# Out:
# Naïve Bayes Multinomial (sin TruncatedSVD):
# F1-macro scores por fold: [0.41666667 0.41666667 0.42551064 0.41747573 0.42638889]
# F1-macro promedio: 0.4205

# %% [markdown]
# ## Support Vector Machine

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.metrics import classification_report, f1_score, make_scorer

# Definir el modelo y los hiperparámetros a probar
svc = SVC(random_state=0)
param_grid = {
    'kernel': ['linear', 'rbf'],
    'C': [0.1, 1, 10],
    'gamma': ['scale', 'auto']
}

# Configurar validación cruzada y búsqueda de hiperparámetros
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)
grid_search = GridSearchCV(
    svc,
    param_grid,
    scoring=make_scorer(f1_score, average='macro'),
    cv=cv,
    n_jobs=-1,
    verbose=2
)

# Ejecutar búsqueda
grid_search.fit(X_train_reduced, train_df['Tag Value'])

# Imprimir mejores resultados
print("Mejor configuración encontrada:")
print(grid_search.best_params_)
print(f"Mejor F1-macro: {grid_search.best_score_:.4f}")

print("\nResultados detallados por configuración:")
means = grid_search.cv_results_['mean_test_score']
stds = grid_search.cv_results_['std_test_score']
params = grid_search.cv_results_['params']
for mean, std, param in zip(means, stds, params):
    print(f"{param} -> F1-macro: {mean:.4f} (+/-{std:.4f})")
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV] END ..................C=0.1, gamma=scale, kernel=linear; total time=   0.3s
# [CV] END ..................C=0.1, gamma=scale, kernel=linear; total time=   0.2s
# [CV] END ..................C=0.1, gamma=scale, kernel=linear; total time=   0.2s
# [CV] END ..................C=0.1, gamma=scale, kernel=linear; total time=   0.2s
# [CV] END ..................C=0.1, gamma=scale, kernel=linear; total time=   0.2s
# [CV] END .....................C=0.1, gamma=scale, kernel=rbf; total time=   0.4s
# [CV] END .....................C=0.1, gamma=scale, kernel=rbf; total time=   0.4s
# [CV] END .....................C=0.1, gamma=scale, kernel=rbf; total time=   0.3s
# [CV] END ...................C=0.1, gamma=auto, kernel=linear; total time=   0.2s
# [CV] END ...................C=0.1, gamma=auto, kernel=linear; total time=   0.2s
# [CV] END .....................C=0.1, gamma=scale, kernel=rbf; total time=   0.3s
# [CV] END .....................C=0.1, gamma=scale, kernel=rbf; total time=   0.3s
# [CV] END ...................C=0.1, gamma=auto, kernel=linear; total time=   0.2s
# [CV] END ...................C=0.1, gamma=auto, kernel=linear; total time=   0.2s
# [CV] END ......................C=0.1, gamma=auto, kernel=rbf; total time=   0.2s
# [CV] END ...................C=0.1, gamma=auto, kernel=linear; total time=   0.2s
# [CV] END ......................C=0.1, gamma=auto, kernel=rbf; total time=   0.3s
# [CV] END ......................C=0.1, gamma=auto, kernel=rbf; total time=   0.2s
# [CV] END ......................C=0.1, gamma=auto, kernel=rbf; total time=   0.2s[CV] END ......................C=0.1, gamma=auto, kernel=rbf; total time=   0.3s
#
# [CV] END ....................C=1, gamma=scale, kernel=linear; total time=   0.2s
# [CV] END ....................C=1, gamma=scale, kernel=linear; total time=   0.2s
# [CV] END ....................C=1, gamma=scale, kernel=linear; total time=   0.1s
# [CV] END ....................C=1, gamma=scale, kernel=linear; total time=   0.2s
# [CV] END ....................C=1, gamma=scale, kernel=linear; total time=   0.2s
# [CV] END .......................C=1, gamma=scale, kernel=rbf; total time=   0.3s
# [CV] END .......................C=1, gamma=scale, kernel=rbf; total time=   0.3s
# [CV] END .......................C=1, gamma=scale, kernel=rbf; total time=   0.3s
# [CV] END .......................C=1, gamma=scale, kernel=rbf; total time=   0.2s
# [CV] END .....................C=1, gamma=auto, kernel=linear; total time=   0.2s
# [CV] END .....................C=1, gamma=auto, kernel=linear; total time=   0.2s
# [CV] END .......................C=1, gamma=scale, kernel=rbf; total time=   0.3s
# [CV] END .....................C=1, gamma=auto, kernel=linear; total time=   0.2s
# [CV] END .....................C=1, gamma=auto, kernel=linear; total time=   0.2s
# [CV] END .....................C=1, gamma=auto, kernel=linear; total time=   0.2s
# [CV] END ........................C=1, gamma=auto, kernel=rbf; total time=   0.3s
# [CV] END ........................C=1, gamma=auto, kernel=rbf; total time=   0.2s
# [CV] END ........................C=1, gamma=auto, kernel=rbf; total time=   0.3s
# [CV] END ........................C=1, gamma=auto, kernel=rbf; total time=   0.2s
# [CV] END ...................C=10, gamma=scale, kernel=linear; total time=   0.2s
# [CV] END ........................C=1, gamma=auto, kernel=rbf; total time=   0.2s
# [CV] END ...................C=10, gamma=scale, kernel=linear; total time=   0.2s
# [CV] END ...................C=10, gamma=scale, kernel=linear; total time=   0.2s
# [CV] END ...................C=10, gamma=scale, kernel=linear; total time=   0.2s
# [CV] END ...................C=10, gamma=scale, kernel=linear; total time=   0.2s
# [CV] END ......................C=10, gamma=scale, kernel=rbf; total time=   0.4s
# [CV] END ......................C=10, gamma=scale, kernel=rbf; total time=   0.4s
# [CV] END ......................C=10, gamma=scale, kernel=rbf; total time=   0.4s
# [CV] END ......................C=10, gamma=scale, kernel=rbf; total time=   0.4s
# [CV] END ....................C=10, gamma=auto, kernel=linear; total time=   0.2s
# [CV] END ....................C=10, gamma=auto, kernel=linear; total time=   0.2s
# [CV] END ....................C=10, gamma=auto, kernel=linear; total time=   0.2s
# [CV] END ....................C=10, gamma=auto, kernel=linear; total time=   0.2s
# [CV] END ......................C=10, gamma=scale, kernel=rbf; total time=   0.4s
# [CV] END ....................C=10, gamma=auto, kernel=linear; total time=   0.2s
# [CV] END .......................C=10, gamma=auto, kernel=rbf; total time=   0.3s
# [CV] END .......................C=10, gamma=auto, kernel=rbf; total time=   0.3s
# [CV] END .......................C=10, gamma=auto, kernel=rbf; total time=   0.3s
# [CV] END .......................C=10, gamma=auto, kernel=rbf; total time=   0.2s
# [CV] END .......................C=10, gamma=auto, kernel=rbf; total time=   0.2s
# Mejor configuración encontrada:
# {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# Mejor F1-macro: 0.7112
#
# Resultados detallados por configuración:
# {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear'} -> F1-macro: 0.4170 (+/-0.0004)
# {'C': 0.1, 'gamma': 'scale', 'kernel': 'rbf'} -> F1-macro: 0.4258 (+/-0.0056)
# {'C': 0.1, 'gamma': 'auto', 'kernel': 'linear'} -> F1-macro: 0.4170 (+/-0.0004)
# {'C': 0.1, 'gamma': 'auto', 'kernel': 'rbf'} -> F1-macro: 0.4170 (+/-0.0004)
# {'C': 1, 'gamma': 'scale', 'kernel': 'linear'} -> F1-macro: 0.6279 (+/-0.0099)
# {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'} -> F1-macro: 0.6824 (+/-0.0188)
# {'C': 1, 'gamma': 'auto', 'kernel': 'linear'} -> F1-macro: 0.6279 (+/-0.0099)
# {'C': 1, 'gamma': 'auto', 'kernel': 'rbf'} -> F1-macro: 0.4170 (+/-0.0004)
# {'C': 10, 'gamma': 'scale', 'kernel': 'linear'} -> F1-macro: 0.6995 (+/-0.0208)
# {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'} -> F1-macro: 0.7112 (+/-0.0093)
# {'C': 10, 'gamma': 'auto', 'kernel': 'linear'} -> F1-macro: 0.6995 (+/-0.0208)
# {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'} -> F1-macro: 0.4481 (+/-0.0137)

# %%
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score

# Definir el modelo de SVC
svc_model = SVC(C=10,gamma='scale',kernel='rbf', random_state=0)

# Evaluar el modelo con validación cruzada usando las representaciones reducidas (X_train_reduced)
svc_scores = cross_val_score(svc_model, X_train_reduced, train_df['Tag Value'], cv=5, scoring='f1_macro')

# Imprimir los resultados
print("Support Vector Machines (SVC):")
print(f"F1-macro scores por fold: {svc_scores}")
print(f"F1-macro promedio: {svc_scores.mean():.4f}")
# Out:
# Support Vector Machines (SVC):
# F1-macro scores por fold: [0.73289278 0.69827348 0.71557209 0.724375   0.6968186 ]
# F1-macro promedio: 0.7136

# %%
from sklearn.metrics import classification_report, confusion_matrix

# Entrenar el modelo en todo el conjunto de entrenamiento
svc_model.fit(X_train_reduced, train_df['Tag Value'])

# Predecir sobre el conjunto de validación/desarrollo
y_pred = svc_model.predict(X_dev_reduced)
y_true = dev_df['Tag Value']

# Imprimir el reporte de clasificación
print("Reporte de clasificación:")
print(classification_report(y_true, y_pred, digits=4))

# Imprimir la matriz de confusión
print("Matriz de confusión:")
print(confusion_matrix(y_true, y_pred))
# Out:
# Reporte de clasificación:
#               precision    recall  f1-score   support
#
#            0     0.8122    0.9080    0.8574       500
#            1     0.6738    0.4750    0.5572       200
#
#     accuracy                         0.7843       700
#    macro avg     0.7430    0.6915    0.7073       700
# weighted avg     0.7726    0.7843    0.7716       700
#
# Matriz de confusión:
# [[454  46]
#  [105  95]]

# %% [markdown]
# ## Multi-layer Perceptron (MLPClassifier)

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.metrics import f1_score, make_scorer

# Definir el modelo y los hiperparámetros a probar
mlp = MLPClassifier(random_state=0, max_iter=2000)
param_grid = {
    'hidden_layer_sizes': [(50,), (100,), (100, 50), (150,)],
    'alpha': [0.0001, 0.001, 0.01],
    'solver': ['adam', 'lbfgs'],
}

# Configurar validación cruzada y búsqueda de hiperparámetros
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)
grid_search = GridSearchCV(
    mlp,
    param_grid,
    scoring=make_scorer(f1_score, average='macro'),
    cv=cv,
    n_jobs=-1,
    verbose=2
)

# Ejecutar búsqueda
grid_search.fit(X_train_reduced, train_df['Tag Value'])

# Imprimir mejores resultados
print("Mejor configuración encontrada:")
print(grid_search.best_params_)
print(f"Mejor F1-macro: {grid_search.best_score_:.4f}")

print("\nResultados detallados por configuración:")
means = grid_search.cv_results_['mean_test_score']
stds = grid_search.cv_results_['std_test_score']
params = grid_search.cv_results_['params']
for mean, std, param in zip(means, stds, params):
    print(f"{param} -> F1-macro: {mean:.4f} (+/-{std:.4f})")
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV] END alpha=0.0001, hidden_layer_sizes=(50,), solver=adam; total time=  11.3s
# [CV] END alpha=0.0001, hidden_layer_sizes=(50,), solver=adam; total time=  11.5s
# [CV] END alpha=0.0001, hidden_layer_sizes=(50,), solver=adam; total time=  12.6s
# [CV] END alpha=0.0001, hidden_layer_sizes=(50,), solver=adam; total time=  12.9s
# [CV] END alpha=0.0001, hidden_layer_sizes=(50,), solver=lbfgs; total time=   2.6s
# [CV] END alpha=0.0001, hidden_layer_sizes=(50,), solver=lbfgs; total time=   2.4s
# [CV] END alpha=0.0001, hidden_layer_sizes=(50,), solver=lbfgs; total time=   2.8s
# [CV] END alpha=0.0001, hidden_layer_sizes=(50,), solver=lbfgs; total time=   2.0s
# [CV] END alpha=0.0001, hidden_layer_sizes=(50,), solver=lbfgs; total time=   1.9s
# [CV] END alpha=0.0001, hidden_layer_sizes=(50,), solver=adam; total time=  11.2s
# [CV] END alpha=0.0001, hidden_layer_sizes=(100,), solver=adam; total time=  10.2s
# [CV] END alpha=0.0001, hidden_layer_sizes=(100,), solver=adam; total time=  10.6s
# [CV] END alpha=0.0001, hidden_layer_sizes=(100,), solver=adam; total time=  10.4s
# [CV] END alpha=0.0001, hidden_layer_sizes=(100,), solver=lbfgs; total time=   3.6s
# [CV] END alpha=0.0001, hidden_layer_sizes=(100,), solver=lbfgs; total time=   3.6s
# [CV] END alpha=0.0001, hidden_layer_sizes=(100,), solver=lbfgs; total time=   3.3s
# [CV] END alpha=0.0001, hidden_layer_sizes=(100,), solver=adam; total time=  11.5s
# [CV] END alpha=0.0001, hidden_layer_sizes=(100,), solver=lbfgs; total time=   4.1s
# [CV] END alpha=0.0001, hidden_layer_sizes=(100,), solver=lbfgs; total time=   3.2s
# [CV] END alpha=0.0001, hidden_layer_sizes=(100, 50), solver=adam; total time=   4.0s
# [CV] END alpha=0.0001, hidden_layer_sizes=(100, 50), solver=adam; total time=   3.5s
# [CV] END alpha=0.0001, hidden_layer_sizes=(100,), solver=adam; total time=  13.4s
# [CV] END alpha=0.0001, hidden_layer_sizes=(100, 50), solver=adam; total time=   3.9s
# [CV] END alpha=0.0001, hidden_layer_sizes=(100, 50), solver=adam; total time=   4.2s
# [CV] END alpha=0.0001, hidden_layer_sizes=(100, 50), solver=adam; total time=   4.2s
# [CV] END alpha=0.0001, hidden_layer_sizes=(100, 50), solver=lbfgs; total time=   6.7s
# [CV] END alpha=0.0001, hidden_layer_sizes=(100, 50), solver=lbfgs; total time=   6.6s
# [CV] END alpha=0.0001, hidden_layer_sizes=(100, 50), solver=lbfgs; total time=   6.7s
# [CV] END alpha=0.0001, hidden_layer_sizes=(100, 50), solver=lbfgs; total time=   7.8s
# [CV] END alpha=0.0001, hidden_layer_sizes=(100, 50), solver=lbfgs; total time=   8.4s
# [CV] END alpha=0.0001, hidden_layer_sizes=(150,), solver=adam; total time=  12.8s
# [CV] END alpha=0.0001, hidden_layer_sizes=(150,), solver=adam; total time=  13.3s
# [CV] END alpha=0.0001, hidden_layer_sizes=(150,), solver=adam; total time=  14.1s
# [CV] END alpha=0.0001, hidden_layer_sizes=(150,), solver=adam; total time=  13.0s
# [CV] END alpha=0.0001, hidden_layer_sizes=(150,), solver=lbfgs; total time=   4.4s
# [CV] END alpha=0.0001, hidden_layer_sizes=(150,), solver=lbfgs; total time=   5.4s
# [CV] END alpha=0.0001, hidden_layer_sizes=(150,), solver=lbfgs; total time=   4.5s
# [CV] END alpha=0.0001, hidden_layer_sizes=(150,), solver=lbfgs; total time=   5.5s
# [CV] END alpha=0.0001, hidden_layer_sizes=(150,), solver=lbfgs; total time=   5.0s
# [CV] END alpha=0.0001, hidden_layer_sizes=(150,), solver=adam; total time=  14.3s
# [CV] END .alpha=0.001, hidden_layer_sizes=(50,), solver=adam; total time=   9.0s
# [CV] END .alpha=0.001, hidden_layer_sizes=(50,), solver=adam; total time=   8.6s
# [CV] END .alpha=0.001, hidden_layer_sizes=(50,), solver=adam; total time=   9.3s
# [CV] END .alpha=0.001, hidden_layer_sizes=(50,), solver=adam; total time=   9.8s
# [CV] END alpha=0.001, hidden_layer_sizes=(50,), solver=lbfgs; total time=   4.0s
# [CV] END alpha=0.001, hidden_layer_sizes=(50,), solver=lbfgs; total time=   3.4s
# [CV] END alpha=0.001, hidden_layer_sizes=(50,), solver=lbfgs; total time=   5.1s
# [CV] END alpha=0.001, hidden_layer_sizes=(50,), solver=lbfgs; total time=   3.2s
# [CV] END alpha=0.001, hidden_layer_sizes=(50,), solver=lbfgs; total time=   3.2s
# [CV] END .alpha=0.001, hidden_layer_sizes=(50,), solver=adam; total time=  10.6s
# [CV] END alpha=0.001, hidden_layer_sizes=(100,), solver=adam; total time=  11.1s
# [CV] END alpha=0.001, hidden_layer_sizes=(100,), solver=adam; total time=  11.3s
# [CV] END alpha=0.001, hidden_layer_sizes=(100,), solver=adam; total time=  10.8s
# [CV] END alpha=0.001, hidden_layer_sizes=(100,), solver=adam; total time=  12.0s
# [CV] END alpha=0.001, hidden_layer_sizes=(100,), solver=lbfgs; total time=   4.3s
# [CV] END alpha=0.001, hidden_layer_sizes=(100,), solver=lbfgs; total time=   7.0s
# [CV] END alpha=0.001, hidden_layer_sizes=(100,), solver=lbfgs; total time=   6.3s
# [CV] END alpha=0.001, hidden_layer_sizes=(100,), solver=adam; total time=  13.7s
# [CV] END alpha=0.001, hidden_layer_sizes=(100,), solver=lbfgs; total time=   7.5s
# [CV] END alpha=0.001, hidden_layer_sizes=(100, 50), solver=adam; total time=   4.0s
# [CV] END alpha=0.001, hidden_layer_sizes=(100,), solver=lbfgs; total time=   6.6s
# [CV] END alpha=0.001, hidden_layer_sizes=(100, 50), solver=adam; total time=   3.6s
# [CV] END alpha=0.001, hidden_layer_sizes=(100, 50), solver=adam; total time=   4.6s
# [CV] END alpha=0.001, hidden_layer_sizes=(100, 50), solver=adam; total time=   4.1s
# [CV] END alpha=0.001, hidden_layer_sizes=(100, 50), solver=adam; total time=   4.8s
# [CV] END alpha=0.001, hidden_layer_sizes=(100, 50), solver=lbfgs; total time=   8.1s
# [CV] END alpha=0.001, hidden_layer_sizes=(100, 50), solver=lbfgs; total time=   7.6s
# [CV] END alpha=0.001, hidden_layer_sizes=(100, 50), solver=lbfgs; total time=   7.0s
# [CV] END alpha=0.001, hidden_layer_sizes=(100, 50), solver=lbfgs; total time=  10.6s
# [CV] END alpha=0.001, hidden_layer_sizes=(100, 50), solver=lbfgs; total time=   7.4s
# [CV] END alpha=0.001, hidden_layer_sizes=(150,), solver=adam; total time=  13.0s
# [CV] END alpha=0.001, hidden_layer_sizes=(150,), solver=adam; total time=  13.2s
# [CV] END alpha=0.001, hidden_layer_sizes=(150,), solver=adam; total time=  14.0s
# [CV] END alpha=0.001, hidden_layer_sizes=(150,), solver=adam; total time=  14.6s
# [CV] END alpha=0.001, hidden_layer_sizes=(150,), solver=lbfgs; total time=   8.1s
# [CV] END alpha=0.001, hidden_layer_sizes=(150,), solver=lbfgs; total time=  10.4s
# [CV] END alpha=0.001, hidden_layer_sizes=(150,), solver=adam; total time=  15.6s
# [CV] END alpha=0.001, hidden_layer_sizes=(150,), solver=lbfgs; total time=   8.0s
# [CV] END alpha=0.001, hidden_layer_sizes=(150,), solver=lbfgs; total time=   9.4s
# [CV] END alpha=0.001, hidden_layer_sizes=(150,), solver=lbfgs; total time=   8.0s
# [CV] END ..alpha=0.01, hidden_layer_sizes=(50,), solver=adam; total time=  10.8s
# [CV] END ..alpha=0.01, hidden_layer_sizes=(50,), solver=adam; total time=  11.4s
# [CV] END ..alpha=0.01, hidden_layer_sizes=(50,), solver=adam; total time=   8.1s
# [CV] END ..alpha=0.01, hidden_layer_sizes=(50,), solver=adam; total time=  11.6s
# /home/omar/Documentos/ESCOM/NLP/ClickbaitDetection/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END .alpha=0.01, hidden_layer_sizes=(50,), solver=lbfgs; total time=  10.7s
# [CV] END ..alpha=0.01, hidden_layer_sizes=(50,), solver=adam; total time=  11.9s
# /home/omar/Documentos/ESCOM/NLP/ClickbaitDetection/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END .alpha=0.01, hidden_layer_sizes=(50,), solver=lbfgs; total time=  11.5s
# /home/omar/Documentos/ESCOM/NLP/ClickbaitDetection/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END .alpha=0.01, hidden_layer_sizes=(50,), solver=lbfgs; total time=  11.0s
# /home/omar/Documentos/ESCOM/NLP/ClickbaitDetection/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END .alpha=0.01, hidden_layer_sizes=(50,), solver=lbfgs; total time=  11.8s
# /home/omar/Documentos/ESCOM/NLP/ClickbaitDetection/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END .alpha=0.01, hidden_layer_sizes=(50,), solver=lbfgs; total time=  11.5s
# [CV] END .alpha=0.01, hidden_layer_sizes=(100,), solver=adam; total time=  12.8s
# [CV] END .alpha=0.01, hidden_layer_sizes=(100,), solver=adam; total time=  11.8s
# [CV] END .alpha=0.01, hidden_layer_sizes=(100,), solver=adam; total time=  10.8s
# [CV] END .alpha=0.01, hidden_layer_sizes=(100,), solver=adam; total time=  12.3s
# [CV] END .alpha=0.01, hidden_layer_sizes=(100,), solver=adam; total time=  13.2s
# /home/omar/Documentos/ESCOM/NLP/ClickbaitDetection/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END alpha=0.01, hidden_layer_sizes=(100,), solver=lbfgs; total time=  23.7s
# /home/omar/Documentos/ESCOM/NLP/ClickbaitDetection/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END alpha=0.01, hidden_layer_sizes=(100,), solver=lbfgs; total time=  25.0s
# /home/omar/Documentos/ESCOM/NLP/ClickbaitDetection/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END alpha=0.01, hidden_layer_sizes=(100,), solver=lbfgs; total time=  24.5s
# /home/omar/Documentos/ESCOM/NLP/ClickbaitDetection/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END alpha=0.01, hidden_layer_sizes=(100,), solver=lbfgs; total time=  23.4s
# [CV] END alpha=0.01, hidden_layer_sizes=(100, 50), solver=adam; total time=   5.2s
# [CV] END alpha=0.01, hidden_layer_sizes=(100, 50), solver=adam; total time=   5.5s
# [CV] END alpha=0.01, hidden_layer_sizes=(100, 50), solver=adam; total time=   6.5s
# [CV] END alpha=0.01, hidden_layer_sizes=(100, 50), solver=adam; total time=   5.9s
# [CV] END alpha=0.01, hidden_layer_sizes=(100, 50), solver=adam; total time=   6.4s
# /home/omar/Documentos/ESCOM/NLP/ClickbaitDetection/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END alpha=0.01, hidden_layer_sizes=(100,), solver=lbfgs; total time=  23.3s
# [CV] END alpha=0.01, hidden_layer_sizes=(100, 50), solver=lbfgs; total time=  23.1s
# [CV] END alpha=0.01, hidden_layer_sizes=(100, 50), solver=lbfgs; total time=  26.0s
# [CV] END alpha=0.01, hidden_layer_sizes=(100, 50), solver=lbfgs; total time=  21.8s
# [CV] END alpha=0.01, hidden_layer_sizes=(100, 50), solver=lbfgs; total time=  34.2s
# [CV] END .alpha=0.01, hidden_layer_sizes=(150,), solver=adam; total time=  16.9s
# [CV] END .alpha=0.01, hidden_layer_sizes=(150,), solver=adam; total time=  16.6s
# [CV] END .alpha=0.01, hidden_layer_sizes=(150,), solver=adam; total time=  14.7s
# [CV] END alpha=0.01, hidden_layer_sizes=(100, 50), solver=lbfgs; total time=  24.6s
# [CV] END .alpha=0.01, hidden_layer_sizes=(150,), solver=adam; total time=  16.4s
# [CV] END .alpha=0.01, hidden_layer_sizes=(150,), solver=adam; total time=  17.2s
# [CV] END alpha=0.01, hidden_layer_sizes=(150,), solver=lbfgs; total time=  25.3s
# /home/omar/Documentos/ESCOM/NLP/ClickbaitDetection/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END alpha=0.01, hidden_layer_sizes=(150,), solver=lbfgs; total time=  40.0s
# /home/omar/Documentos/ESCOM/NLP/ClickbaitDetection/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END alpha=0.01, hidden_layer_sizes=(150,), solver=lbfgs; total time=  38.2s
# /home/omar/Documentos/ESCOM/NLP/ClickbaitDetection/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END alpha=0.01, hidden_layer_sizes=(150,), solver=lbfgs; total time=  37.9s
# [CV] END alpha=0.01, hidden_layer_sizes=(150,), solver=lbfgs; total time=  30.6s
# Mejor configuración encontrada:
# {'alpha': 0.0001, 'hidden_layer_sizes': (150,), 'solver': 'adam'}
# Mejor F1-macro: 0.7312
#
# Resultados detallados por configuración:
# {'alpha': 0.0001, 'hidden_layer_sizes': (50,), 'solver': 'adam'} -> F1-macro: 0.7104 (+/-0.0163)
# {'alpha': 0.0001, 'hidden_layer_sizes': (50,), 'solver': 'lbfgs'} -> F1-macro: 0.6636 (+/-0.0133)
# {'alpha': 0.0001, 'hidden_layer_sizes': (100,), 'solver': 'adam'} -> F1-macro: 0.7248 (+/-0.0156)
# {'alpha': 0.0001, 'hidden_layer_sizes': (100,), 'solver': 'lbfgs'} -> F1-macro: 0.6952 (+/-0.0173)
# {'alpha': 0.0001, 'hidden_layer_sizes': (100, 50), 'solver': 'adam'} -> F1-macro: 0.7182 (+/-0.0227)
# {'alpha': 0.0001, 'hidden_layer_sizes': (100, 50), 'solver': 'lbfgs'} -> F1-macro: 0.6810 (+/-0.0166)
# {'alpha': 0.0001, 'hidden_layer_sizes': (150,), 'solver': 'adam'} -> F1-macro: 0.7312 (+/-0.0170)
# {'alpha': 0.0001, 'hidden_layer_sizes': (150,), 'solver': 'lbfgs'} -> F1-macro: 0.6997 (+/-0.0302)
# {'alpha': 0.001, 'hidden_layer_sizes': (50,), 'solver': 'adam'} -> F1-macro: 0.7058 (+/-0.0217)
# {'alpha': 0.001, 'hidden_layer_sizes': (50,), 'solver': 'lbfgs'} -> F1-macro: 0.6782 (+/-0.0192)
# {'alpha': 0.001, 'hidden_layer_sizes': (100,), 'solver': 'adam'} -> F1-macro: 0.7241 (+/-0.0177)
# {'alpha': 0.001, 'hidden_layer_sizes': (100,), 'solver': 'lbfgs'} -> F1-macro: 0.6822 (+/-0.0153)
# {'alpha': 0.001, 'hidden_layer_sizes': (100, 50), 'solver': 'adam'} -> F1-macro: 0.7153 (+/-0.0232)
# {'alpha': 0.001, 'hidden_layer_sizes': (100, 50), 'solver': 'lbfgs'} -> F1-macro: 0.6847 (+/-0.0111)
# {'alpha': 0.001, 'hidden_layer_sizes': (150,), 'solver': 'adam'} -> F1-macro: 0.7189 (+/-0.0174)
# {'alpha': 0.001, 'hidden_layer_sizes': (150,), 'solver': 'lbfgs'} -> F1-macro: 0.6955 (+/-0.0216)
# {'alpha': 0.01, 'hidden_layer_sizes': (50,), 'solver': 'adam'} -> F1-macro: 0.7111 (+/-0.0157)
# {'alpha': 0.01, 'hidden_layer_sizes': (50,), 'solver': 'lbfgs'} -> F1-macro: 0.6946 (+/-0.0237)
# {'alpha': 0.01, 'hidden_layer_sizes': (100,), 'solver': 'adam'} -> F1-macro: 0.7229 (+/-0.0207)
# {'alpha': 0.01, 'hidden_layer_sizes': (100,), 'solver': 'lbfgs'} -> F1-macro: 0.7007 (+/-0.0246)
# {'alpha': 0.01, 'hidden_layer_sizes': (100, 50), 'solver': 'adam'} -> F1-macro: 0.7158 (+/-0.0288)
# {'alpha': 0.01, 'hidden_layer_sizes': (100, 50), 'solver': 'lbfgs'} -> F1-macro: 0.6961 (+/-0.0221)
# {'alpha': 0.01, 'hidden_layer_sizes': (150,), 'solver': 'adam'} -> F1-macro: 0.7180 (+/-0.0175)
# {'alpha': 0.01, 'hidden_layer_sizes': (150,), 'solver': 'lbfgs'} -> F1-macro: 0.6976 (+/-0.0219)

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import cross_val_score

# Definir el modelo de MLP
mlp_model = MLPClassifier(hidden_layer_sizes=(150,), max_iter=3000, alpha=0.0001, solver='adam', random_state=0)

# Evaluar el modelo con validación cruzada usando las representaciones reducidas (X_train_reduced)
mlp_scores = cross_val_score(mlp_model, X_train_reduced, train_df['Tag Value'], cv=5, scoring='f1_macro')

# Imprimir los resultados
print("Multi-layer Perceptron (MLPClassifier):")
print(f"F1-macro scores por fold: {mlp_scores}")
print(f"F1-macro promedio: {mlp_scores.mean():.4f}")
# Out:
# Multi-layer Perceptron (MLPClassifier):
# F1-macro scores por fold: [0.73593496 0.68865827 0.73672702 0.7336485  0.69515131]
# F1-macro promedio: 0.7180

# %%
from sklearn.metrics import classification_report, confusion_matrix

# Entrenar el modelo en todo el conjunto de entrenamiento
mlp_model.fit(X_train_reduced, train_df['Tag Value'])

# Predecir sobre el conjunto de validación/desarrollo
y_pred = mlp_model.predict(X_dev_reduced)
y_true = dev_df['Tag Value']

# Imprimir el reporte de clasificación
print("Reporte de clasificación:")
print(classification_report(y_true, y_pred, digits=4))

# Imprimir la matriz de confusión
print("Matriz de confusión:")
print(confusion_matrix(y_true, y_pred))
# Out:
# Reporte de clasificación:
#               precision    recall  f1-score   support
#
#            0     0.8174    0.9040    0.8585       500
#            1     0.6735    0.4950    0.5706       200
#
#     accuracy                         0.7871       700
#    macro avg     0.7454    0.6995    0.7146       700
# weighted avg     0.7762    0.7871    0.7762       700
#
# Matriz de confusión:
# [[452  48]
#  [101  99]]

# %% [markdown]
# ## Random forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.metrics import f1_score, make_scorer

# Definir el modelo y los hiperparámetros a probar
rf = RandomForestClassifier(random_state=0)
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# Configurar validación cruzada y búsqueda de hiperparámetros
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)
grid_search = GridSearchCV(
    rf,
    param_grid,
    scoring=make_scorer(f1_score, average='macro'),
    cv=cv,
    n_jobs=-1,
    verbose=2
)

# Ejecutar búsqueda
grid_search.fit(X_train_reduced, train_df['Tag Value'])

# Imprimir mejores resultados
print("Mejor configuración encontrada:")
print(grid_search.best_params_)
print(f"Mejor F1-macro: {grid_search.best_score_:.4f}")

print("\nResultados detallados por configuración:")
means = grid_search.cv_results_['mean_test_score']
stds = grid_search.cv_results_['std_test_score']
params = grid_search.cv_results_['params']
for mean, std, param in zip(means, stds, params):
    print(f"{param} -> F1-macro: {mean:.4f} (+/-{std:.4f})")
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   1.6s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   1.8s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   1.9s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   1.9s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   1.4s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   2.7s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   2.8s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   2.9s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   2.8s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   2.8s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   5.3s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   5.6s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   5.0s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.8s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   4.4s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.7s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   3.8s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.7s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.7s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.7s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.8s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   3.4s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   3.5s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   3.5s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   3.4s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   3.6s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.7s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.6s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.8s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.7s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.8s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   3.6s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   3.4s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   3.6s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   3.7s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   3.7s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.7s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.7s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.8s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.7s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.8s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.3s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.4s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.4s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.3s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.8s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.8s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.5s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.7s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.8s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.7s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.7s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.8s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   3.4s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   3.4s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   3.4s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.8s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   3.4s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.8s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.6s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   3.7s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.8s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.7s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.7s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.8s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   3.4s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   3.4s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   3.5s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   3.6s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   3.6s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.6s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.6s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.6s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.7s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.7s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   3.2s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   3.1s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.8s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   3.3s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   3.5s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.8s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.8s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.8s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.8s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   3.3s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.7s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.5s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.6s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.7s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.7s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   3.1s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   3.1s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.8s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   3.4s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.8s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   3.3s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.8s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.8s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.8s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   3.4s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.6s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.6s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.7s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.7s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.6s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   3.2s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   3.2s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   3.2s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   3.3s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.5s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.6s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   3.3s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.6s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.4s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.7s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   3.1s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   3.2s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   3.2s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.7s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   3.1s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   3.1s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.5s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.6s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.5s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.6s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.5s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   3.1s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   3.1s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   3.2s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   3.3s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   3.0s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.5s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.5s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.6s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.6s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.5s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   3.2s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   3.1s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   3.1s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   3.1s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.7s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   3.2s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.5s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.6s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.7s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.4s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.5s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.1s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.1s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.0s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.0s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.1s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.5s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.5s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.5s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.6s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.5s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   3.0s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   3.0s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   3.2s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   3.0s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.7s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   3.1s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.5s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.6s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.5s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.5s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.6s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   3.0s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   3.1s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   3.0s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.7s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   3.1s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.7s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.7s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.7s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   3.2s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.5s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.4s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.5s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.5s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.6s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   2.8s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   2.9s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.7s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   3.0s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   3.1s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.7s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.7s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   2.9s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.5s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.4s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.4s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.6s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.7s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   3.0s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   3.0s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.7s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   3.1s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   2.9s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.7s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.7s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.7s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   3.0s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.5s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.5s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.6s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.5s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.5s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   3.0s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   3.0s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   2.9s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   2.8s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   3.1s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.8s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.9s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   2.0s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   2.0s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   2.0s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   3.8s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   3.8s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   3.9s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   3.9s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   4.0s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.9s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   2.0s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.9s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.9s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   2.0s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   3.8s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   3.7s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.9s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   3.9s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   4.0s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.9s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   1.0s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   1.0s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   1.0s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   3.9s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.9s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.9s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.9s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   2.1s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   2.2s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   3.9s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   3.6s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   3.9s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   3.9s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   3.9s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.8s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.9s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.9s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.8s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.9s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.7s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.7s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.6s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.6s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.8s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.8s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.8s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.8s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.8s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.8s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   3.5s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   3.5s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.8s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   3.7s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   3.6s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.9s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.9s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.9s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   1.0s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   3.7s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.8s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.9s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.8s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.8s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   3.5s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   3.5s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   3.6s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   3.6s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   3.8s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.8s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.6s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.8s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   3.2s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   3.2s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   3.3s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.8s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   3.3s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.8s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.8s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.8s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   3.4s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.6s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   3.2s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   3.2s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   3.3s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.8s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   3.3s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.8s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.8s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.8s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.9s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   3.4s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.6s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.7s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   3.2s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   3.3s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   3.4s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   3.3s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   3.3s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.9s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.9s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.9s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.9s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   2.1s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   3.8s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   3.9s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   4.0s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   4.1s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   3.9s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.8s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.9s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   2.1s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.9s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   2.0s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   3.9s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   3.7s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   3.9s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.9s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.9s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   4.1s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   1.0s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.9s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   1.0s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   4.0s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.9s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.9s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   2.0s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.9s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   2.0s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   3.9s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   3.9s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   3.8s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   3.8s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   3.9s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.8s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.9s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.8s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.8s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   2.0s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.5s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.6s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.8s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.6s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.7s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.8s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.8s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.9s
# ...
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.8s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.8s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.7s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.6s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   3.6s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.7s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.7s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.7s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   3.4s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   3.2s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   1.0s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   3.4s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   3.4s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.8s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.9s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.9s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.9s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   3.6s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.7s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.7s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.8s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.7s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.7s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   3.5s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   3.5s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   3.3s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   3.3s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   3.0s
# Mejor configuración encontrada:
# {'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 50}
# Mejor F1-macro: 0.6476
#
# Resultados detallados por configuración:
# {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50} -> F1-macro: 0.6300 (+/-0.0166)
# {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100} -> F1-macro: 0.6382 (+/-0.0102)
# {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200} -> F1-macro: 0.6372 (+/-0.0157)
# {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 50} -> F1-macro: 0.6322 (+/-0.0196)
# {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100} -> F1-macro: 0.6292 (+/-0.0146)
# {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200} -> F1-macro: 0.6333 (+/-0.0151)
# {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 50} -> F1-macro: 0.6372 (+/-0.0244)
# {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 100} -> F1-macro: 0.6320 (+/-0.0205)
# {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 200} -> F1-macro: 0.6302 (+/-0.0134)
# {'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 50} -> F1-macro: 0.6353 (+/-0.0263)
# {'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100} -> F1-macro: 0.6390 (+/-0.0193)
# {'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 200} -> F1-macro: 0.6364 (+/-0.0219)
# {'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 50} -> F1-macro: 0.6327 (+/-0.0222)
# {'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100} -> F1-macro: 0.6399 (+/-0.0164)
# {'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 200} -> F1-macro: 0.6303 (+/-0.0150)
# {'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 50} -> F1-macro: 0.6375 (+/-0.0180)
# {'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 100} -> F1-macro: 0.6317 (+/-0.0170)
# {'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 200} -> F1-macro: 0.6219 (+/-0.0122)
# {'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 50} -> F1-macro: 0.6189 (+/-0.0200)
# {'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 100} -> F1-macro: 0.6164 (+/-0.0122)
# {'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 200} -> F1-macro: 0.6119 (+/-0.0099)
# {'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 50} -> F1-macro: 0.6189 (+/-0.0200)
# {'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 100} -> F1-macro: 0.6164 (+/-0.0122)
# {'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 200} -> F1-macro: 0.6119 (+/-0.0099)
# {'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 50} -> F1-macro: 0.6216 (+/-0.0115)
# {'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 100} -> F1-macro: 0.6146 (+/-0.0163)
# {'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 200} -> F1-macro: 0.6163 (+/-0.0154)
# {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50} -> F1-macro: 0.6158 (+/-0.0164)
# {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100} -> F1-macro: 0.6141 (+/-0.0113)
# {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200} -> F1-macro: 0.6102 (+/-0.0172)
# {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 50} -> F1-macro: 0.6083 (+/-0.0106)
# {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100} -> F1-macro: 0.6086 (+/-0.0130)
# {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200} -> F1-macro: 0.6115 (+/-0.0171)
# {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 50} -> F1-macro: 0.6148 (+/-0.0109)
# {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 100} -> F1-macro: 0.6163 (+/-0.0175)
# {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 200} -> F1-macro: 0.6091 (+/-0.0122)
# {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 50} -> F1-macro: 0.6202 (+/-0.0152)
# {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100} -> F1-macro: 0.6182 (+/-0.0212)
# {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 200} -> F1-macro: 0.6142 (+/-0.0213)
# {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 50} -> F1-macro: 0.6193 (+/-0.0198)
# {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100} -> F1-macro: 0.6105 (+/-0.0180)
# {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 200} -> F1-macro: 0.6083 (+/-0.0229)
# {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 50} -> F1-macro: 0.6106 (+/-0.0156)
# {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 100} -> F1-macro: 0.6145 (+/-0.0084)
# {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 200} -> F1-macro: 0.6160 (+/-0.0142)
# {'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 50} -> F1-macro: 0.6136 (+/-0.0256)
# {'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 100} -> F1-macro: 0.6169 (+/-0.0119)
# {'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 200} -> F1-macro: 0.6082 (+/-0.0128)
# {'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 50} -> F1-macro: 0.6136 (+/-0.0256)
# {'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 100} -> F1-macro: 0.6169 (+/-0.0119)
# {'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 200} -> F1-macro: 0.6082 (+/-0.0128)
# {'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 50} -> F1-macro: 0.6107 (+/-0.0280)
# {'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 100} -> F1-macro: 0.6073 (+/-0.0201)
# {'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 200} -> F1-macro: 0.6070 (+/-0.0117)
# {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50} -> F1-macro: 0.6353 (+/-0.0193)
# {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100} -> F1-macro: 0.6445 (+/-0.0258)
# {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200} -> F1-macro: 0.6360 (+/-0.0183)
# {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 50} -> F1-macro: 0.6224 (+/-0.0166)
# {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100} -> F1-macro: 0.6276 (+/-0.0078)
# {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200} -> F1-macro: 0.6273 (+/-0.0094)
# {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 50} -> F1-macro: 0.6316 (+/-0.0150)
# {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 100} -> F1-macro: 0.6349 (+/-0.0196)
# {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 200} -> F1-macro: 0.6309 (+/-0.0144)
# {'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 50} -> F1-macro: 0.6476 (+/-0.0238)
# {'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100} -> F1-macro: 0.6445 (+/-0.0198)
# {'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 200} -> F1-macro: 0.6362 (+/-0.0196)
# {'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 50} -> F1-macro: 0.6311 (+/-0.0197)
# {'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100} -> F1-macro: 0.6352 (+/-0.0099)
# {'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 200} -> F1-macro: 0.6269 (+/-0.0187)
# {'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 50} -> F1-macro: 0.6354 (+/-0.0148)
# {'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 100} -> F1-macro: 0.6246 (+/-0.0184)
# {'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 200} -> F1-macro: 0.6267 (+/-0.0133)
# {'max_depth': 20, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 50} -> F1-macro: 0.6194 (+/-0.0165)
# {'max_depth': 20, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 100} -> F1-macro: 0.6176 (+/-0.0189)
# {'max_depth': 20, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 200} -> F1-macro: 0.6111 (+/-0.0120)
# {'max_depth': 20, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 50} -> F1-macro: 0.6194 (+/-0.0165)
# {'max_depth': 20, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 100} -> F1-macro: 0.6176 (+/-0.0189)
# {'max_depth': 20, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 200} -> F1-macro: 0.6111 (+/-0.0120)
# {'max_depth': 20, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 50} -> F1-macro: 0.6205 (+/-0.0089)
# {'max_depth': 20, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 100} -> F1-macro: 0.6101 (+/-0.0204)
# {'max_depth': 20, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 200} -> F1-macro: 0.6169 (+/-0.0180)
# {'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50} -> F1-macro: 0.6295 (+/-0.0164)
# {'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100} -> F1-macro: 0.6378 (+/-0.0104)
# {'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200} -> F1-macro: 0.6372 (+/-0.0157)
# {'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 50} -> F1-macro: 0.6310 (+/-0.0199)
# {'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100} -> F1-macro: 0.6292 (+/-0.0146)
# {'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200} -> F1-macro: 0.6321 (+/-0.0157)
# {'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 50} -> F1-macro: 0.6372 (+/-0.0244)
# {'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 100} -> F1-macro: 0.6320 (+/-0.0205)
# {'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 200} -> F1-macro: 0.6290 (+/-0.0141)
# {'max_depth': 30, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 50} -> F1-macro: 0.6353 (+/-0.0263)
# {'max_depth': 30, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100} -> F1-macro: 0.6390 (+/-0.0193)
# {'max_depth': 30, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 200} -> F1-macro: 0.6364 (+/-0.0219)
# {'max_depth': 30, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 50} -> F1-macro: 0.6315 (+/-0.0243)
# {'max_depth': 30, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100} -> F1-macro: 0.6399 (+/-0.0164)
# {'max_depth': 30, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 200} -> F1-macro: 0.6315 (+/-0.0141)
# {'max_depth': 30, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 50} -> F1-macro: 0.6375 (+/-0.0180)
# {'max_depth': 30, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 100} -> F1-macro: 0.6317 (+/-0.0170)
# {'max_depth': 30, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 200} -> F1-macro: 0.6219 (+/-0.0122)
# {'max_depth': 30, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 50} -> F1-macro: 0.6189 (+/-0.0200)
# {'max_depth': 30, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 100} -> F1-macro: 0.6164 (+/-0.0122)
# {'max_depth': 30, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 200} -> F1-macro: 0.6119 (+/-0.0099)
# {'max_depth': 30, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 50} -> F1-macro: 0.6189 (+/-0.0200)
# {'max_depth': 30, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 100} -> F1-macro: 0.6164 (+/-0.0122)
# {'max_depth': 30, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 200} -> F1-macro: 0.6119 (+/-0.0099)
# {'max_depth': 30, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 50} -> F1-macro: 0.6216 (+/-0.0115)
# {'max_depth': 30, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 100} -> F1-macro: 0.6146 (+/-0.0163)
# {'max_depth': 30, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 200} -> F1-macro: 0.6163 (+/-0.0154)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

# Definir el modelo de Random Forest
rf_model = RandomForestClassifier(max_depth=20, min_samples_leaf=2, min_samples_split=2,n_estimators=50, random_state=0)

# Evaluar el modelo con validación cruzada usando las representaciones reducidas (X_train_reduced)
rf_scores = cross_val_score(rf_model, X_train_reduced, train_df['Tag Value'], cv=5, scoring='f1_macro')

# Imprimir los resultados
print("Random Forest:")
print(f"F1-macro scores por fold: {rf_scores}")
print(f"F1-macro promedio: {rf_scores.mean():.4f}")
# Out:
# Random Forest:
# F1-macro scores por fold: [0.63638439 0.61043478 0.62040129 0.64437595 0.63211679]
# F1-macro promedio: 0.6287

# %%
from sklearn.metrics import classification_report, confusion_matrix

# Entrenar el modelo en todo el conjunto de entrenamiento
rf_model.fit(X_train_reduced, train_df['Tag Value'])

# Predecir sobre el conjunto de validación/desarrollo
y_pred = rf_model.predict(X_dev_reduced)
y_true = dev_df['Tag Value']

# Imprimir el reporte de clasificación
print("Reporte de clasificación:")
print(classification_report(y_true, y_pred, digits=4))

# Imprimir la matriz de confusión
print("Matriz de confusión:")
print(confusion_matrix(y_true, y_pred))
# Out:
# Reporte de clasificación:
#               precision    recall  f1-score   support
#
#            0     0.7707    0.9880    0.8659       500
#            1     0.8983    0.2650    0.4093       200
#
#     accuracy                         0.7814       700
#    macro avg     0.8345    0.6265    0.6376       700
# weighted avg     0.8071    0.7814    0.7354       700
#
# Matriz de confusión:
# [[494   6]
#  [147  53]]

# %% [markdown]
# ## Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.metrics import f1_score, make_scorer

# Definir el modelo y los hiperparámetros a probar
gb = GradientBoostingClassifier(random_state=0)
param_grid = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.01, 0.05, 0.1],
    'max_depth': [2, 3, 5],
    'subsample': [0.8, 1.0]
}

# Configurar validación cruzada y búsqueda de hiperparámetros
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)
grid_search = GridSearchCV(
    gb,
    param_grid,
    scoring=make_scorer(f1_score, average='macro'),
    cv=cv,
    n_jobs=-1,
    verbose=2
)

# Ejecutar búsqueda
grid_search.fit(X_train_reduced, train_df['Tag Value'])

# Imprimir mejores resultados
print("Mejor configuración encontrada:")
print(grid_search.best_params_)
print(f"Mejor F1-macro: {grid_search.best_score_:.4f}")

print("\nResultados detallados por configuración:")
means = grid_search.cv_results_['mean_test_score']
stds = grid_search.cv_results_['std_test_score']
params = grid_search.cv_results_['params']
for mean, std, param in zip(means, stds, params):
    print(f"{param} -> F1-macro: {mean:.4f} (+/-{std:.4f})")
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.8; total time=   3.2s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.8; total time=   3.6s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.8; total time=   3.7s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.8; total time=   3.8s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.8; total time=   2.9s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=1.0; total time=   3.6s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=1.0; total time=   3.7s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=1.0; total time=   3.7s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=1.0; total time=   3.6s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=1.0; total time=   3.2s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.8; total time=   4.4s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.8; total time=   4.6s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.8; total time=   3.8s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.8; total time=   3.4s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.8; total time=   3.5s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=1.0; total time=   4.6s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=1.0; total time=   4.7s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=1.0; total time=   4.5s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=1.0; total time=   4.8s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=1.0; total time=   4.6s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.8; total time=   6.8s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.8; total time=   7.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.8; total time=   7.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.8; total time=   7.2s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.8; total time=   7.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=1.0; total time=   9.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=1.0; total time=   9.3s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=1.0; total time=   9.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.8; total time=   2.8s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.8; total time=   2.8s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=1.0; total time=   9.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.8; total time=   2.8s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.8; total time=   2.8s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.8; total time=   2.7s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=1.0; total time=   9.6s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=1.0; total time=   3.4s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=1.0; total time=   3.4s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=1.0; total time=   3.5s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=1.0; total time=   3.6s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=1.0; total time=   3.6s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8; total time=   5.6s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8; total time=   5.4s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8; total time=   5.6s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8; total time=   5.5s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8; total time=   5.5s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1.0; total time=   6.9s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1.0; total time=   7.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1.0; total time=   7.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1.0; total time=   7.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1.0; total time=   7.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.8; total time=  11.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.8; total time=  11.4s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.8; total time=  11.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.8; total time=  11.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.8; total time=  11.4s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=1.0; total time=  14.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=1.0; total time=  14.4s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=1.0; total time=  14.7s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.8; total time=   4.4s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.8; total time=   4.6s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=1.0; total time=  14.5s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.8; total time=   4.7s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=1.0; total time=  14.3s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.8; total time=   4.6s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.8; total time=   4.5s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=1.0; total time=   5.7s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=1.0; total time=   5.6s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=1.0; total time=   5.7s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=1.0; total time=   5.9s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=1.0; total time=   5.8s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.8; total time=   9.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.8; total time=   9.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.8; total time=   8.9s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.8; total time=   8.9s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.8; total time=   9.3s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=1.0; total time=  11.4s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=1.0; total time=  12.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=1.0; total time=  11.8s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=1.0; total time=  11.6s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=1.0; total time=  11.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.8; total time=  18.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.8; total time=  18.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.8; total time=  18.4s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.8; total time=  18.5s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.8; total time=  18.4s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=1.0; total time=  23.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=1.0; total time=  23.2s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=50, subsample=0.8; total time=   2.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=1.0; total time=  23.2s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=50, subsample=0.8; total time=   2.0s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=50, subsample=0.8; total time=   1.9s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=50, subsample=0.8; total time=   2.0s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=50, subsample=0.8; total time=   2.0s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=50, subsample=1.0; total time=   2.5s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=50, subsample=1.0; total time=   2.6s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=1.0; total time=  23.6s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=50, subsample=1.0; total time=   2.5s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=50, subsample=1.0; total time=   2.6s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=50, subsample=1.0; total time=   2.5s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=100, subsample=0.8; total time=   4.0s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=100, subsample=0.8; total time=   3.9s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=100, subsample=0.8; total time=   4.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=1.0; total time=  23.2s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=100, subsample=0.8; total time=   3.9s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=100, subsample=0.8; total time=   4.1s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=100, subsample=1.0; total time=   5.2s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=100, subsample=1.0; total time=   5.2s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=100, subsample=1.0; total time=   4.9s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=100, subsample=1.0; total time=   5.0s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=100, subsample=1.0; total time=   5.3s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=200, subsample=0.8; total time=   8.6s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=200, subsample=0.8; total time=   8.1s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=200, subsample=0.8; total time=   8.1s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=200, subsample=0.8; total time=   7.8s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=200, subsample=0.8; total time=   8.2s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=200, subsample=1.0; total time=  10.2s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=200, subsample=1.0; total time=  10.4s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=200, subsample=1.0; total time=  10.0s
# [CV] END learning_rate=0.05, max_depth=3, n_estimators=50, subsample=0.8; total time=   3.0s
# [CV] END learning_rate=0.05, max_depth=3, n_estimators=50, subsample=0.8; total time=   3.0s
# [CV] END learning_rate=0.05, max_depth=3, n_estimators=50, subsample=0.8; total time=   3.0s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=200, subsample=1.0; total time=  10.2s
# [CV] END learning_rate=0.05, max_depth=3, n_estimators=50, subsample=0.8; total time=   2.8s
# [CV] END learning_rate=0.05, max_depth=3, n_estimators=50, subsample=0.8; total time=   3.1s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=200, subsample=1.0; total time=  10.2s
# [CV] END learning_rate=0.05, max_depth=3, n_estimators=50, subsample=1.0; total time=   4.0s
# [CV] END learning_rate=0.05, max_depth=3, n_estimators=50, subsample=1.0; total time=   3.7s
# [CV] END learning_rate=0.05, max_depth=3, n_estimators=50, subsample=1.0; total time=   3.7s
# [CV] END learning_rate=0.05, max_depth=3, n_estimators=50, subsample=1.0; total time=   3.9s
# [CV] END learning_rate=0.05, max_depth=3, n_estimators=50, subsample=1.0; total time=   3.8s
# [CV] END learning_rate=0.05, max_depth=3, n_estimators=100, subsample=0.8; total time=   5.8s
# [CV] END learning_rate=0.05, max_depth=3, n_estimators=100, subsample=0.8; total time=   6.0s
# [CV] END learning_rate=0.05, max_depth=3, n_estimators=100, subsample=0.8; total time=   6.0s
# [CV] END learning_rate=0.05, max_depth=3, n_estimators=100, subsample=0.8; total time=   5.9s
# [CV] END learning_rate=0.05, max_depth=3, n_estimators=100, subsample=0.8; total time=   5.9s
# [CV] END learning_rate=0.05, max_depth=3, n_estimators=100, subsample=1.0; total time=   7.6s
# [CV] END learning_rate=0.05, max_depth=3, n_estimators=100, subsample=1.0; total time=   7.8s
# [CV] END learning_rate=0.05, max_depth=3, n_estimators=100, subsample=1.0; total time=   7.7s
# [CV] END learning_rate=0.05, max_depth=3, n_estimators=100, subsample=1.0; total time=   7.6s
# [CV] END learning_rate=0.05, max_depth=3, n_estimators=100, subsample=1.0; total time=   7.6s
# [CV] END learning_rate=0.05, max_depth=3, n_estimators=200, subsample=0.8; total time=  12.2s
# [CV] END learning_rate=0.05, max_depth=3, n_estimators=200, subsample=0.8; total time=  11.8s
# [CV] END learning_rate=0.05, max_depth=3, n_estimators=200, subsample=0.8; total time=  11.8s
# [CV] END learning_rate=0.05, max_depth=3, n_estimators=200, subsample=0.8; total time=  12.0s
# [CV] END learning_rate=0.05, max_depth=3, n_estimators=200, subsample=0.8; total time=  11.9s
# [CV] END learning_rate=0.05, max_depth=3, n_estimators=200, subsample=1.0; total time=  15.1s
# [CV] END learning_rate=0.05, max_depth=3, n_estimators=200, subsample=1.0; total time=  15.4s
# [CV] END learning_rate=0.05, max_depth=3, n_estimators=200, subsample=1.0; total time=  15.1s
# [CV] END learning_rate=0.05, max_depth=5, n_estimators=50, subsample=0.8; total time=   4.7s
# [CV] END learning_rate=0.05, max_depth=5, n_estimators=50, subsample=0.8; total time=   4.7s
# [CV] END learning_rate=0.05, max_depth=3, n_estimators=200, subsample=1.0; total time=  15.3s
# [CV] END learning_rate=0.05, max_depth=5, n_estimators=50, subsample=0.8; total time=   4.7s
# [CV] END learning_rate=0.05, max_depth=5, n_estimators=50, subsample=0.8; total time=   4.8s
# [CV] END learning_rate=0.05, max_depth=3, n_estimators=200, subsample=1.0; total time=  15.4s
# [CV] END learning_rate=0.05, max_depth=5, n_estimators=50, subsample=0.8; total time=   4.9s
# [CV] END learning_rate=0.05, max_depth=5, n_estimators=50, subsample=1.0; total time=   5.9s
# [CV] END learning_rate=0.05, max_depth=5, n_estimators=50, subsample=1.0; total time=   5.9s
# [CV] END learning_rate=0.05, max_depth=5, n_estimators=50, subsample=1.0; total time=   5.9s
# [CV] END learning_rate=0.05, max_depth=5, n_estimators=50, subsample=1.0; total time=   5.9s
# [CV] END learning_rate=0.05, max_depth=5, n_estimators=50, subsample=1.0; total time=   6.0s
# [CV] END learning_rate=0.05, max_depth=5, n_estimators=100, subsample=0.8; total time=   9.2s
# [CV] END learning_rate=0.05, max_depth=5, n_estimators=100, subsample=0.8; total time=   9.4s
# [CV] END learning_rate=0.05, max_depth=5, n_estimators=100, subsample=0.8; total time=   9.6s
# [CV] END learning_rate=0.05, max_depth=5, n_estimators=100, subsample=0.8; total time=   9.4s
# [CV] END learning_rate=0.05, max_depth=5, n_estimators=100, subsample=0.8; total time=   9.3s
# [CV] END learning_rate=0.05, max_depth=5, n_estimators=100, subsample=1.0; total time=  11.9s
# [CV] END learning_rate=0.05, max_depth=5, n_estimators=100, subsample=1.0; total time=  11.9s
# [CV] END learning_rate=0.05, max_depth=5, n_estimators=100, subsample=1.0; total time=  11.8s
# [CV] END learning_rate=0.05, max_depth=5, n_estimators=100, subsample=1.0; total time=  11.9s
# [CV] END learning_rate=0.05, max_depth=5, n_estimators=100, subsample=1.0; total time=  11.8s
# [CV] END learning_rate=0.05, max_depth=5, n_estimators=200, subsample=0.8; total time=  18.9s
# [CV] END learning_rate=0.05, max_depth=5, n_estimators=200, subsample=0.8; total time=  19.1s
# [CV] END learning_rate=0.05, max_depth=5, n_estimators=200, subsample=0.8; total time=  19.1s
# [CV] END learning_rate=0.05, max_depth=5, n_estimators=200, subsample=0.8; total time=  18.7s
# [CV] END learning_rate=0.05, max_depth=5, n_estimators=200, subsample=0.8; total time=  18.9s
# [CV] END learning_rate=0.05, max_depth=5, n_estimators=200, subsample=1.0; total time=  24.2s
# [CV] END learning_rate=0.05, max_depth=5, n_estimators=200, subsample=1.0; total time=  24.2s
# [CV] END learning_rate=0.05, max_depth=5, n_estimators=200, subsample=1.0; total time=  24.0s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=50, subsample=0.8; total time=   2.1s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=50, subsample=0.8; total time=   2.1s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=50, subsample=0.8; total time=   2.1s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=50, subsample=0.8; total time=   1.9s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=50, subsample=0.8; total time=   2.1s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=50, subsample=1.0; total time=   2.5s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=50, subsample=1.0; total time=   2.6s
# [CV] END learning_rate=0.05, max_depth=5, n_estimators=200, subsample=1.0; total time=  23.9s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=50, subsample=1.0; total time=   2.6s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=50, subsample=1.0; total time=   2.6s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=50, subsample=1.0; total time=   2.7s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=100, subsample=0.8; total time=   4.1s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=100, subsample=0.8; total time=   4.2s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=100, subsample=0.8; total time=   4.4s
# [CV] END learning_rate=0.05, max_depth=5, n_estimators=200, subsample=1.0; total time=  24.9s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=100, subsample=0.8; total time=   4.0s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=100, subsample=0.8; total time=   4.1s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=100, subsample=1.0; total time=   5.3s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=100, subsample=1.0; total time=   5.3s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=100, subsample=1.0; total time=   5.1s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=100, subsample=1.0; total time=   5.2s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=100, subsample=1.0; total time=   5.2s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=200, subsample=0.8; total time=   7.9s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=200, subsample=0.8; total time=   8.6s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=200, subsample=0.8; total time=   8.2s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=200, subsample=0.8; total time=   8.1s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=200, subsample=0.8; total time=   8.3s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=200, subsample=1.0; total time=  10.4s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=200, subsample=1.0; total time=  10.6s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.8; total time=   3.0s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=200, subsample=1.0; total time=  10.5s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.8; total time=   3.0s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.8; total time=   3.3s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=200, subsample=1.0; total time=  10.6s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.8; total time=   3.2s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.8; total time=   3.3s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=50, subsample=1.0; total time=   4.2s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=200, subsample=1.0; total time=  11.2s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=50, subsample=1.0; total time=   4.2s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=50, subsample=1.0; total time=   4.2s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=50, subsample=1.0; total time=   4.1s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=50, subsample=1.0; total time=   4.1s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.8; total time=   6.3s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.8; total time=   6.6s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.8; total time=   6.5s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.8; total time=   6.6s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.8; total time=   6.7s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1.0; total time=   8.0s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1.0; total time=   7.9s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1.0; total time=   8.1s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1.0; total time=   8.4s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1.0; total time=   8.0s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.8; total time=  12.8s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.8; total time=  12.9s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.8; total time=  12.4s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.8; total time=  13.0s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.8; total time=  12.9s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=1.0; total time=  16.6s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=1.0; total time=  16.3s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=1.0; total time=  16.5s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.8; total time=   5.1s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.8; total time=   5.0s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=1.0; total time=  16.3s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.8; total time=   5.3s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=1.0; total time=  16.0s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.8; total time=   5.1s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.8; total time=   5.1s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=50, subsample=1.0; total time=   6.5s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=50, subsample=1.0; total time=   6.7s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=50, subsample=1.0; total time=   6.4s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=50, subsample=1.0; total time=   6.5s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=50, subsample=1.0; total time=   6.4s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.8; total time=  10.4s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.8; total time=  10.1s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.8; total time=  10.2s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.8; total time=  10.4s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.8; total time=  10.2s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=1.0; total time=  13.4s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=1.0; total time=  13.0s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=1.0; total time=  12.7s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=1.0; total time=  12.7s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=1.0; total time=  13.7s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.8; total time=  21.2s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.8; total time=  21.4s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.8; total time=  21.6s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.8; total time=  21.2s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.8; total time=  20.5s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=1.0; total time=  27.5s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=1.0; total time=  26.9s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=1.0; total time=  26.0s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=1.0; total time=  25.3s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=1.0; total time=  22.9s
# Mejor configuración encontrada:
# {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 200, 'subsample': 0.8}
# Mejor F1-macro: 0.7092
#
# Resultados detallados por configuración:
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 50, 'subsample': 0.8} -> F1-macro: 0.5061 (+/-0.0294)
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 50, 'subsample': 1.0} -> F1-macro: 0.5270 (+/-0.0351)
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 100, 'subsample': 0.8} -> F1-macro: 0.5423 (+/-0.0151)
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 100, 'subsample': 1.0} -> F1-macro: 0.5445 (+/-0.0158)
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 200, 'subsample': 0.8} -> F1-macro: 0.5797 (+/-0.0202)
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 200, 'subsample': 1.0} -> F1-macro: 0.5715 (+/-0.0183)
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.8} -> F1-macro: 0.5246 (+/-0.0121)
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50, 'subsample': 1.0} -> F1-macro: 0.5367 (+/-0.0203)
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.8} -> F1-macro: 0.5577 (+/-0.0151)
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 1.0} -> F1-macro: 0.5585 (+/-0.0188)
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200, 'subsample': 0.8} -> F1-macro: 0.6169 (+/-0.0151)
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200, 'subsample': 1.0} -> F1-macro: 0.6116 (+/-0.0165)
# {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50, 'subsample': 0.8} -> F1-macro: 0.5350 (+/-0.0148)
# {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50, 'subsample': 1.0} -> F1-macro: 0.5468 (+/-0.0182)
# {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100, 'subsample': 0.8} -> F1-macro: 0.5953 (+/-0.0161)
# {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100, 'subsample': 1.0} -> F1-macro: 0.6087 (+/-0.0221)
# {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 200, 'subsample': 0.8} -> F1-macro: 0.6451 (+/-0.0137)
# {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 200, 'subsample': 1.0} -> F1-macro: 0.6431 (+/-0.0245)
# {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 50, 'subsample': 0.8} -> F1-macro: 0.6043 (+/-0.0168)
# {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 50, 'subsample': 1.0} -> F1-macro: 0.5922 (+/-0.0133)
# {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 100, 'subsample': 0.8} -> F1-macro: 0.6455 (+/-0.0109)
# {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 100, 'subsample': 1.0} -> F1-macro: 0.6496 (+/-0.0229)
# {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 200, 'subsample': 0.8} -> F1-macro: 0.6780 (+/-0.0239)
# {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 200, 'subsample': 1.0} -> F1-macro: 0.6755 (+/-0.0133)
# {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.8} -> F1-macro: 0.6344 (+/-0.0106)
# {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50, 'subsample': 1.0} -> F1-macro: 0.6350 (+/-0.0198)
# {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.8} -> F1-macro: 0.6696 (+/-0.0152)
# {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100, 'subsample': 1.0} -> F1-macro: 0.6658 (+/-0.0142)
# {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 200, 'subsample': 0.8} -> F1-macro: 0.6953 (+/-0.0244)
# {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 200, 'subsample': 1.0} -> F1-macro: 0.6812 (+/-0.0193)
# {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 50, 'subsample': 0.8} -> F1-macro: 0.6661 (+/-0.0182)
# {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 50, 'subsample': 1.0} -> F1-macro: 0.6566 (+/-0.0229)
# {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 100, 'subsample': 0.8} -> F1-macro: 0.6851 (+/-0.0164)
# {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 100, 'subsample': 1.0} -> F1-macro: 0.6759 (+/-0.0179)
# {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 200, 'subsample': 0.8} -> F1-macro: 0.6999 (+/-0.0185)
# {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 200, 'subsample': 1.0} -> F1-macro: 0.6781 (+/-0.0165)
# {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 50, 'subsample': 0.8} -> F1-macro: 0.6517 (+/-0.0139)
# {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 50, 'subsample': 1.0} -> F1-macro: 0.6493 (+/-0.0235)
# {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100, 'subsample': 0.8} -> F1-macro: 0.6772 (+/-0.0302)
# {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100, 'subsample': 1.0} -> F1-macro: 0.6742 (+/-0.0218)
# {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 200, 'subsample': 0.8} -> F1-macro: 0.6932 (+/-0.0163)
# {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 200, 'subsample': 1.0} -> F1-macro: 0.6845 (+/-0.0152)
# {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.8} -> F1-macro: 0.6602 (+/-0.0159)
# {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50, 'subsample': 1.0} -> F1-macro: 0.6678 (+/-0.0092)
# {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.8} -> F1-macro: 0.6963 (+/-0.0290)
# {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'subsample': 1.0} -> F1-macro: 0.6830 (+/-0.0203)
# {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 200, 'subsample': 0.8} -> F1-macro: 0.7092 (+/-0.0207)
# {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 200, 'subsample': 1.0} -> F1-macro: 0.6922 (+/-0.0237)
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50, 'subsample': 0.8} -> F1-macro: 0.6790 (+/-0.0125)
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50, 'subsample': 1.0} -> F1-macro: 0.6836 (+/-0.0273)
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'subsample': 0.8} -> F1-macro: 0.6912 (+/-0.0164)
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'subsample': 1.0} -> F1-macro: 0.6773 (+/-0.0145)
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200, 'subsample': 0.8} -> F1-macro: 0.6944 (+/-0.0105)
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200, 'subsample': 1.0} -> F1-macro: 0.6787 (+/-0.0141)

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import cross_val_score

# Definir el modelo de Gradient Boosting
gb_model = GradientBoostingClassifier(subsample=0.8,n_estimators=200, learning_rate=0.1, max_depth=3, random_state=0)

# Evaluar el modelo con validación cruzada usando las representaciones reducidas (X_train_reduced)
gb_scores = cross_val_score(gb_model, X_train_reduced, train_df['Tag Value'], cv=5, scoring='f1_macro')

# Imprimir los resultados
print("Gradient Boosting:")
print(f"F1-macro scores por fold: {gb_scores}")
print(f"F1-macro promedio: {gb_scores.mean():.4f}")
# Out:
# Gradient Boosting:
# F1-macro scores por fold: [0.68936679 0.68235178 0.69388507 0.69161989 0.7166752 ]
# F1-macro promedio: 0.6948

# %%
from sklearn.metrics import classification_report, confusion_matrix

# Entrenar el modelo en todo el conjunto de entrenamiento
gb_model.fit(X_train_reduced, train_df['Tag Value'])

# Predecir sobre el conjunto de validación/desarrollo
y_pred = gb_model.predict(X_dev_reduced)
y_true = dev_df['Tag Value']

# Imprimir el reporte de clasificación
print("Reporte de clasificación:")
print(classification_report(y_true, y_pred, digits=4))

# Imprimir la matriz de confusión
print("Matriz de confusión:")
print(confusion_matrix(y_true, y_pred))
# Out:
# Reporte de clasificación:
#               precision    recall  f1-score   support
#
#            0     0.8014    0.9360    0.8635       500
#            1     0.7241    0.4200    0.5316       200
#
#     accuracy                         0.7886       700
#    macro avg     0.7628    0.6780    0.6976       700
# weighted avg     0.7793    0.7886    0.7687       700
#
# Matriz de confusión:
# [[468  32]
#  [116  84]]
