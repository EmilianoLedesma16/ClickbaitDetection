# %% [markdown]
# # Entranamiento de modelos usando cleaned text

# %%
import pandas as pd

# Cargar los conjuntos de entrenamiento y desarrollo
train_df = pd.read_csv("../data/TA1C_dataset_detection_train_split.csv")
dev_df = pd.read_csv("../data/TA1C_dataset_detection_dev_split.csv")

# Verificar las columnas disponibles
print(train_df.columns)
# Out:
# Index(['Tweet ID', 'Teaser Text', 'Tag Value', 'tokenized_text',
#        'cleaned_text', 'no_stopwords_text', 'lemmatized_text',
#        'tokenized_cleaned_text', 'tokenized_cleaned_text_no_stopwords',
#        'tokenized_cleaned_text_no_stopwords_lemmatized'],
#       dtype='object')

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Probar diferentes configuraciones de n-gramas y representaciones
configurations = [
    {"ngram_range": (1, 1), "representation": "tfidf"},  # Unigramas con TF-IDF
    {"ngram_range": (1, 2), "representation": "tfidf"},  # Unigramas + Bigramas con TF-IDF
    {"ngram_range": (1, 3), "representation": "tfidf"},  # Unigramas + Bigramas + Trigramas con TF-IDF
    {"ngram_range": (1, 2), "representation": "binary"},  # Unigramas + Bigramas con representación binaria
    {"ngram_range": (1, 2), "representation": "frequency"},  # Unigramas + Bigramas con frecuencia
]

for config in configurations:
    print(f"Configuración: ngram_range={config['ngram_range']}, representación={config['representation']}")
    
    # Configurar el vectorizador
    if config["representation"] == "tfidf":
        vectorizer = TfidfVectorizer(ngram_range=config["ngram_range"])
    elif config["representation"] == "binary":
        vectorizer = TfidfVectorizer(ngram_range=config["ngram_range"], binary=True)
    elif config["representation"] == "frequency":
        vectorizer = TfidfVectorizer(ngram_range=config["ngram_range"], use_idf=False)
    
    # Crear representaciones para el conjunto de entrenamiento y desarrollo
    X_train = vectorizer.fit_transform(train_df['cleaned_text'])
    X_dev = vectorizer.transform(dev_df['cleaned_text'])
    
    # Verificar las dimensiones
    print(f"Dimensiones de X_train: {X_train.shape}")
    print(f"Dimensiones de X_dev: {X_dev.shape}")
# Out:
# Configuración: ngram_range=(1, 1), representación=tfidf
# Dimensiones de X_train: (2100, 11222)
# Dimensiones de X_dev: (700, 11222)
# Configuración: ngram_range=(1, 2), representación=tfidf
# Dimensiones de X_train: (2100, 42882)
# Dimensiones de X_dev: (700, 42882)
# Configuración: ngram_range=(1, 3), representación=tfidf
# Dimensiones de X_train: (2100, 82375)
# Dimensiones de X_dev: (700, 82375)
# Configuración: ngram_range=(1, 2), representación=binary
# Dimensiones de X_train: (2100, 42882)
# Dimensiones de X_dev: (700, 42882)
# Configuración: ngram_range=(1, 2), representación=frequency
# Dimensiones de X_train: (2100, 42882)
# Dimensiones de X_dev: (700, 42882)

# %%
from sklearn.decomposition import TruncatedSVD

# Reducir dimensionalidad con TruncatedSVD
svd = TruncatedSVD(n_components=100, random_state=0)  # Reducir a 100 dimensiones
X_train_reduced = svd.fit_transform(X_train)
X_dev_reduced = svd.transform(X_dev)

# Verificar las dimensiones después de la reducción
print(f"Dimensiones reducidas de X_train: {X_train_reduced.shape}")
print(f"Dimensiones reducidas de X_dev: {X_dev_reduced.shape}")
# Out:
# Dimensiones reducidas de X_train: (2100, 100)
# Dimensiones reducidas de X_dev: (700, 100)

# %%
# Convertir etiquetas de texto a valores numéricos
label_mapping = {'Clickbait': 1, 'No': 0}
train_df['Tag Value'] = train_df['Tag Value'].map(label_mapping)
dev_df['Tag Value'] = dev_df['Tag Value'].map(label_mapping)

# %% [markdown]
# ## Logistic Regression y Validación Cruzada

# %%
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import make_scorer, f1_score

# Configurar validación cruzada estratificada
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)

# Definir el modelo
model = LogisticRegression(max_iter=200)

# Evaluar el modelo con validación cruzada usando f1_macro
f1_macro_scorer = make_scorer(f1_score, average='macro')
scores = cross_val_score(model, X_train_reduced, train_df['Tag Value'], cv=cv, scoring=f1_macro_scorer)

# Imprimir los resultados
print(f"F1-macro scores por fold: {scores}")
print(f"F1-macro promedio: {scores.mean():.4f}")
# Out:
# F1-macro scores por fold: [0.56061743 0.55082933 0.60832818 0.584729   0.55255682]
# F1-macro promedio: 0.5714

# %% [markdown]
# ## Naive Bayes Multinominal

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import cross_val_score

# Definir el modelo de Naïve Bayes Multinomial
nb_model = MultinomialNB()

# Evaluar el modelo con validación cruzada usando las representaciones originales (X_train)
nb_scores = cross_val_score(nb_model, X_train, train_df['Tag Value'], cv=5, scoring='f1_macro')

# Imprimir los resultados
print("Naïve Bayes Multinomial (sin TruncatedSVD):")
print(f"F1-macro scores por fold: {nb_scores}")
print(f"F1-macro promedio: {nb_scores.mean():.4f}")
# Out:
# Naïve Bayes Multinomial (sin TruncatedSVD):
# F1-macro scores por fold: [0.41666667 0.41666667 0.42551064 0.43516592 0.42638889]
# F1-macro promedio: 0.4241

# %% [markdown]
# ## Support Vector Machine

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.metrics import classification_report, f1_score, make_scorer

# Definir el modelo y los hiperparámetros a probar
svc = SVC(random_state=0)
param_grid = {
    'kernel': ['linear', 'rbf'],
    'C': [0.1, 1, 10],
    'gamma': ['scale', 'auto']
}

# Configurar validación cruzada y búsqueda de hiperparámetros
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)
grid_search = GridSearchCV(
    svc,
    param_grid,
    scoring=make_scorer(f1_score, average='macro'),
    cv=cv,
    n_jobs=-1,
    verbose=2
)

# Ejecutar búsqueda
grid_search.fit(X_train_reduced, train_df['Tag Value'])

# Imprimir mejores resultados
print("Mejor configuración encontrada:")
print(grid_search.best_params_)
print(f"Mejor F1-macro: {grid_search.best_score_:.4f}")

print("\nResultados detallados por configuración:")
means = grid_search.cv_results_['mean_test_score']
stds = grid_search.cv_results_['std_test_score']
params = grid_search.cv_results_['params']
for mean, std, param in zip(means, stds, params):
    print(f"{param} -> F1-macro: {mean:.4f} (+/-{std:.4f})")
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV] END ..................C=0.1, gamma=scale, kernel=linear; total time=   0.1s
# [CV] END ..................C=0.1, gamma=scale, kernel=linear; total time=   0.1s
# [CV] END ..................C=0.1, gamma=scale, kernel=linear; total time=   0.1s
# [CV] END .....................C=0.1, gamma=scale, kernel=rbf; total time=   0.2s
# [CV] END ..................C=0.1, gamma=scale, kernel=linear; total time=   0.1s
# [CV] END .....................C=0.1, gamma=scale, kernel=rbf; total time=   0.2s
# [CV] END ..................C=0.1, gamma=scale, kernel=linear; total time=   0.1s
# [CV] END .....................C=0.1, gamma=scale, kernel=rbf; total time=   0.2s
# [CV] END .....................C=0.1, gamma=scale, kernel=rbf; total time=   0.2s
# [CV] END ...................C=0.1, gamma=auto, kernel=linear; total time=   0.1s
# [CV] END .....................C=0.1, gamma=scale, kernel=rbf; total time=   0.2s
# [CV] END ...................C=0.1, gamma=auto, kernel=linear; total time=   0.1s
# [CV] END ...................C=0.1, gamma=auto, kernel=linear; total time=   0.1s
# [CV] END ...................C=0.1, gamma=auto, kernel=linear; total time=   0.1s
# [CV] END ...................C=0.1, gamma=auto, kernel=linear; total time=   0.1s
# [CV] END ......................C=0.1, gamma=auto, kernel=rbf; total time=   0.2s
# [CV] END ......................C=0.1, gamma=auto, kernel=rbf; total time=   0.2s
# [CV] END ......................C=0.1, gamma=auto, kernel=rbf; total time=   0.2s
# [CV] END ......................C=0.1, gamma=auto, kernel=rbf; total time=   0.2s
# [CV] END ....................C=1, gamma=scale, kernel=linear; total time=   0.1s
# [CV] END ......................C=0.1, gamma=auto, kernel=rbf; total time=   0.2s
# [CV] END ....................C=1, gamma=scale, kernel=linear; total time=   0.1s
# [CV] END ....................C=1, gamma=scale, kernel=linear; total time=   0.1s
# [CV] END ....................C=1, gamma=scale, kernel=linear; total time=   0.1s
# [CV] END ....................C=1, gamma=scale, kernel=linear; total time=   0.1s
# [CV] END .......................C=1, gamma=scale, kernel=rbf; total time=   0.2s
# [CV] END .......................C=1, gamma=scale, kernel=rbf; total time=   0.2s
# [CV] END .......................C=1, gamma=scale, kernel=rbf; total time=   0.2s
# [CV] END .....................C=1, gamma=auto, kernel=linear; total time=   0.1s
# [CV] END .......................C=1, gamma=scale, kernel=rbf; total time=   0.3s
# [CV] END .....................C=1, gamma=auto, kernel=linear; total time=   0.1s
# [CV] END .......................C=1, gamma=scale, kernel=rbf; total time=   0.2s
# [CV] END .....................C=1, gamma=auto, kernel=linear; total time=   0.1s
# [CV] END .....................C=1, gamma=auto, kernel=linear; total time=   0.1s
# [CV] END .....................C=1, gamma=auto, kernel=linear; total time=   0.1s
# [CV] END ........................C=1, gamma=auto, kernel=rbf; total time=   0.2s
# [CV] END ........................C=1, gamma=auto, kernel=rbf; total time=   0.2s
# [CV] END ........................C=1, gamma=auto, kernel=rbf; total time=   0.2s
# [CV] END ........................C=1, gamma=auto, kernel=rbf; total time=   0.2s
# [CV] END ...................C=10, gamma=scale, kernel=linear; total time=   0.1s
# [CV] END ...................C=10, gamma=scale, kernel=linear; total time=   0.1s
# [CV] END ...................C=10, gamma=scale, kernel=linear; total time=   0.1s
# [CV] END ........................C=1, gamma=auto, kernel=rbf; total time=   0.2s
# [CV] END ...................C=10, gamma=scale, kernel=linear; total time=   0.1s
# [CV] END ...................C=10, gamma=scale, kernel=linear; total time=   0.1s
# [CV] END ......................C=10, gamma=scale, kernel=rbf; total time=   0.3s
# [CV] END ......................C=10, gamma=scale, kernel=rbf; total time=   0.3s
# [CV] END ......................C=10, gamma=scale, kernel=rbf; total time=   0.3s
# [CV] END ......................C=10, gamma=scale, kernel=rbf; total time=   0.3s
# [CV] END ....................C=10, gamma=auto, kernel=linear; total time=   0.1s
# [CV] END ....................C=10, gamma=auto, kernel=linear; total time=   0.1s
# [CV] END ....................C=10, gamma=auto, kernel=linear; total time=   0.1s
# [CV] END ......................C=10, gamma=scale, kernel=rbf; total time=   0.3s
# [CV] END ....................C=10, gamma=auto, kernel=linear; total time=   0.2s
# [CV] END ....................C=10, gamma=auto, kernel=linear; total time=   0.1s
# [CV] END .......................C=10, gamma=auto, kernel=rbf; total time=   0.2s
# [CV] END .......................C=10, gamma=auto, kernel=rbf; total time=   0.2s
# [CV] END .......................C=10, gamma=auto, kernel=rbf; total time=   0.2s
# [CV] END .......................C=10, gamma=auto, kernel=rbf; total time=   0.2s
# [CV] END .......................C=10, gamma=auto, kernel=rbf; total time=   0.1s
# Mejor configuración encontrada:
# {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# Mejor F1-macro: 0.7028
#
# Resultados detallados por configuración:
# {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear'} -> F1-macro: 0.4170 (+/-0.0004)
# {'C': 0.1, 'gamma': 'scale', 'kernel': 'rbf'} -> F1-macro: 0.4205 (+/-0.0044)
# {'C': 0.1, 'gamma': 'auto', 'kernel': 'linear'} -> F1-macro: 0.4170 (+/-0.0004)
# {'C': 0.1, 'gamma': 'auto', 'kernel': 'rbf'} -> F1-macro: 0.4170 (+/-0.0004)
# {'C': 1, 'gamma': 'scale', 'kernel': 'linear'} -> F1-macro: 0.6078 (+/-0.0112)
# {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'} -> F1-macro: 0.6713 (+/-0.0171)
# {'C': 1, 'gamma': 'auto', 'kernel': 'linear'} -> F1-macro: 0.6078 (+/-0.0112)
# {'C': 1, 'gamma': 'auto', 'kernel': 'rbf'} -> F1-macro: 0.4170 (+/-0.0004)
# {'C': 10, 'gamma': 'scale', 'kernel': 'linear'} -> F1-macro: 0.6949 (+/-0.0183)
# {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'} -> F1-macro: 0.7028 (+/-0.0082)
# {'C': 10, 'gamma': 'auto', 'kernel': 'linear'} -> F1-macro: 0.6949 (+/-0.0183)
# {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'} -> F1-macro: 0.4499 (+/-0.0123)

# %%
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score

# Definir el modelo de SVC
svc_model = SVC(C=10,gamma='scale',kernel='rbf', random_state=0)

# Evaluar el modelo con validación cruzada usando las representaciones reducidas (X_train_reduced)
svc_scores = cross_val_score(svc_model, X_train_reduced, train_df['Tag Value'], cv=5, scoring='f1_macro')

# Imprimir los resultados
print("Support Vector Machines (SVC):")
print(f"F1-macro scores por fold: {svc_scores}")
print(f"F1-macro promedio: {svc_scores.mean():.4f}")
# Out:
# Support Vector Machines (SVC):
# F1-macro scores por fold: [0.72903226 0.68934669 0.69275328 0.68484886 0.71503584]
# F1-macro promedio: 0.7022

# %%
from sklearn.metrics import classification_report, confusion_matrix

# Entrenar el modelo en todo el conjunto de entrenamiento
svc_model.fit(X_train_reduced, train_df['Tag Value'])

# Predecir sobre el conjunto de validación/desarrollo
y_pred = svc_model.predict(X_dev_reduced)
y_true = dev_df['Tag Value']

# Imprimir el reporte de clasificación
print("Reporte de clasificación:")
print(classification_report(y_true, y_pred, digits=4))

# Imprimir la matriz de confusión
print("Matriz de confusión:")
print(confusion_matrix(y_true, y_pred))
# Out:
# Reporte de clasificación:
#               precision    recall  f1-score   support
#
#            0     0.7982    0.8940    0.8434       500
#            1     0.6214    0.4350    0.5118       200
#
#     accuracy                         0.7629       700
#    macro avg     0.7098    0.6645    0.6776       700
# weighted avg     0.7477    0.7629    0.7486       700
#
# Matriz de confusión:
# [[447  53]
#  [113  87]]

# %% [markdown]
# ## Multi-layer Perceptron (MLPClassifier)

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.metrics import f1_score, make_scorer

# Definir el modelo y los hiperparámetros a probar
mlp = MLPClassifier(random_state=0, max_iter=2000)
param_grid = {
    'hidden_layer_sizes': [(50,), (100,), (100, 50), (150,)],
    'alpha': [0.0001, 0.001, 0.01],
    'solver': ['adam', 'lbfgs'],
}

# Configurar validación cruzada y búsqueda de hiperparámetros
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)
grid_search = GridSearchCV(
    mlp,
    param_grid,
    scoring=make_scorer(f1_score, average='macro'),
    cv=cv,
    n_jobs=-1,
    verbose=2
)

# Ejecutar búsqueda
grid_search.fit(X_train_reduced, train_df['Tag Value'])

# Imprimir mejores resultados
print("Mejor configuración encontrada:")
print(grid_search.best_params_)
print(f"Mejor F1-macro: {grid_search.best_score_:.4f}")

print("\nResultados detallados por configuración:")
means = grid_search.cv_results_['mean_test_score']
stds = grid_search.cv_results_['std_test_score']
params = grid_search.cv_results_['params']
for mean, std, param in zip(means, stds, params):
    print(f"{param} -> F1-macro: {mean:.4f} (+/-{std:.4f})")
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV] END alpha=0.0001, hidden_layer_sizes=(50,), solver=adam; total time=   9.7s
# [CV] END alpha=0.0001, hidden_layer_sizes=(50,), solver=adam; total time=   9.8s
# [CV] END alpha=0.0001, hidden_layer_sizes=(50,), solver=adam; total time=   9.8s
# [CV] END alpha=0.0001, hidden_layer_sizes=(50,), solver=adam; total time=  10.2s
# [CV] END alpha=0.0001, hidden_layer_sizes=(50,), solver=lbfgs; total time=   1.6s
# [CV] END alpha=0.0001, hidden_layer_sizes=(50,), solver=lbfgs; total time=   1.7s
# [CV] END alpha=0.0001, hidden_layer_sizes=(50,), solver=lbfgs; total time=   1.6s
# [CV] END alpha=0.0001, hidden_layer_sizes=(50,), solver=lbfgs; total time=   1.7s
# [CV] END alpha=0.0001, hidden_layer_sizes=(50,), solver=lbfgs; total time=   1.8s
# [CV] END alpha=0.0001, hidden_layer_sizes=(50,), solver=adam; total time=  10.7s
# [CV] END alpha=0.0001, hidden_layer_sizes=(100,), solver=adam; total time=  10.6s
# [CV] END alpha=0.0001, hidden_layer_sizes=(100,), solver=adam; total time=   9.9s
# [CV] END alpha=0.0001, hidden_layer_sizes=(100,), solver=adam; total time=  10.8s
# [CV] END alpha=0.0001, hidden_layer_sizes=(100,), solver=lbfgs; total time=   2.7s
# [CV] END alpha=0.0001, hidden_layer_sizes=(100,), solver=lbfgs; total time=   2.5s
# [CV] END alpha=0.0001, hidden_layer_sizes=(100,), solver=lbfgs; total time=   2.9s
# [CV] END alpha=0.0001, hidden_layer_sizes=(100,), solver=lbfgs; total time=   4.0s
# [CV] END alpha=0.0001, hidden_layer_sizes=(100,), solver=lbfgs; total time=   3.0s
# [CV] END alpha=0.0001, hidden_layer_sizes=(100,), solver=adam; total time=  12.2s
# [CV] END alpha=0.0001, hidden_layer_sizes=(100, 50), solver=adam; total time=   3.8s
# [CV] END alpha=0.0001, hidden_layer_sizes=(100,), solver=adam; total time=  12.5s
# [CV] END alpha=0.0001, hidden_layer_sizes=(100, 50), solver=adam; total time=   3.4s
# [CV] END alpha=0.0001, hidden_layer_sizes=(100, 50), solver=adam; total time=   4.7s
# [CV] END alpha=0.0001, hidden_layer_sizes=(100, 50), solver=adam; total time=   5.0s
# [CV] END alpha=0.0001, hidden_layer_sizes=(100, 50), solver=adam; total time=   5.4s
# [CV] END alpha=0.0001, hidden_layer_sizes=(100, 50), solver=lbfgs; total time=   7.7s
# [CV] END alpha=0.0001, hidden_layer_sizes=(100, 50), solver=lbfgs; total time=   8.8s
# [CV] END alpha=0.0001, hidden_layer_sizes=(100, 50), solver=lbfgs; total time=   9.0s
# [CV] END alpha=0.0001, hidden_layer_sizes=(100, 50), solver=lbfgs; total time=   7.4s
# [CV] END alpha=0.0001, hidden_layer_sizes=(100, 50), solver=lbfgs; total time=   8.5s
# [CV] END alpha=0.0001, hidden_layer_sizes=(150,), solver=adam; total time=  13.6s
# [CV] END alpha=0.0001, hidden_layer_sizes=(150,), solver=adam; total time=  12.7s
# [CV] END alpha=0.0001, hidden_layer_sizes=(150,), solver=adam; total time=  13.6s
# [CV] END alpha=0.0001, hidden_layer_sizes=(150,), solver=lbfgs; total time=   4.3s
# [CV] END alpha=0.0001, hidden_layer_sizes=(150,), solver=lbfgs; total time=   4.9s
# [CV] END alpha=0.0001, hidden_layer_sizes=(150,), solver=adam; total time=  14.2s
# [CV] END alpha=0.0001, hidden_layer_sizes=(150,), solver=lbfgs; total time=   5.1s
# [CV] END alpha=0.0001, hidden_layer_sizes=(150,), solver=lbfgs; total time=   5.4s
# [CV] END alpha=0.0001, hidden_layer_sizes=(150,), solver=lbfgs; total time=   5.7s
# [CV] END alpha=0.0001, hidden_layer_sizes=(150,), solver=adam; total time=  14.5s
# [CV] END .alpha=0.001, hidden_layer_sizes=(50,), solver=adam; total time=  10.1s
# [CV] END .alpha=0.001, hidden_layer_sizes=(50,), solver=adam; total time=  10.1s
# [CV] END .alpha=0.001, hidden_layer_sizes=(50,), solver=adam; total time=  11.1s
# [CV] END alpha=0.001, hidden_layer_sizes=(50,), solver=lbfgs; total time=   2.8s
# [CV] END .alpha=0.001, hidden_layer_sizes=(50,), solver=adam; total time=  10.7s
# [CV] END alpha=0.001, hidden_layer_sizes=(50,), solver=lbfgs; total time=   2.8s
# [CV] END alpha=0.001, hidden_layer_sizes=(50,), solver=lbfgs; total time=   2.5s
# [CV] END alpha=0.001, hidden_layer_sizes=(50,), solver=lbfgs; total time=   2.3s
# [CV] END alpha=0.001, hidden_layer_sizes=(50,), solver=lbfgs; total time=   2.9s
# [CV] END .alpha=0.001, hidden_layer_sizes=(50,), solver=adam; total time=  11.9s
# [CV] END alpha=0.001, hidden_layer_sizes=(100,), solver=adam; total time=  10.2s
# [CV] END alpha=0.001, hidden_layer_sizes=(100,), solver=adam; total time=  11.0s
# [CV] END alpha=0.001, hidden_layer_sizes=(100,), solver=adam; total time=  11.5s
# [CV] END alpha=0.001, hidden_layer_sizes=(100,), solver=lbfgs; total time=   4.4s
# [CV] END alpha=0.001, hidden_layer_sizes=(100,), solver=adam; total time=  12.4s
# [CV] END alpha=0.001, hidden_layer_sizes=(100,), solver=lbfgs; total time=   4.7s
# [CV] END alpha=0.001, hidden_layer_sizes=(100,), solver=lbfgs; total time=   5.6s
# [CV] END alpha=0.001, hidden_layer_sizes=(100,), solver=lbfgs; total time=   5.5s
# [CV] END alpha=0.001, hidden_layer_sizes=(100,), solver=lbfgs; total time=   5.9s
# [CV] END alpha=0.001, hidden_layer_sizes=(100,), solver=adam; total time=  13.4s
# [CV] END alpha=0.001, hidden_layer_sizes=(100, 50), solver=adam; total time=   4.6s
# [CV] END alpha=0.001, hidden_layer_sizes=(100, 50), solver=adam; total time=   4.0s
# [CV] END alpha=0.001, hidden_layer_sizes=(100, 50), solver=adam; total time=   4.5s
# [CV] END alpha=0.001, hidden_layer_sizes=(100, 50), solver=adam; total time=   5.0s
# [CV] END alpha=0.001, hidden_layer_sizes=(100, 50), solver=adam; total time=   4.6s
# [CV] END alpha=0.001, hidden_layer_sizes=(100, 50), solver=lbfgs; total time=   8.5s
# [CV] END alpha=0.001, hidden_layer_sizes=(100, 50), solver=lbfgs; total time=   8.4s
# [CV] END alpha=0.001, hidden_layer_sizes=(100, 50), solver=lbfgs; total time=   9.6s
# [CV] END alpha=0.001, hidden_layer_sizes=(100, 50), solver=lbfgs; total time=  10.6s
# [CV] END alpha=0.001, hidden_layer_sizes=(100, 50), solver=lbfgs; total time=  11.8s
# [CV] END alpha=0.001, hidden_layer_sizes=(150,), solver=adam; total time=  13.2s
# [CV] END alpha=0.001, hidden_layer_sizes=(150,), solver=adam; total time=  14.7s
# [CV] END alpha=0.001, hidden_layer_sizes=(150,), solver=adam; total time=  14.0s
# [CV] END alpha=0.001, hidden_layer_sizes=(150,), solver=lbfgs; total time=   5.7s
# [CV] END alpha=0.001, hidden_layer_sizes=(150,), solver=lbfgs; total time=   5.5s
# [CV] END alpha=0.001, hidden_layer_sizes=(150,), solver=adam; total time=  14.1s
# [CV] END alpha=0.001, hidden_layer_sizes=(150,), solver=adam; total time=  15.2s
# [CV] END alpha=0.001, hidden_layer_sizes=(150,), solver=lbfgs; total time=   7.9s
# [CV] END alpha=0.001, hidden_layer_sizes=(150,), solver=lbfgs; total time=   8.0s
# [CV] END alpha=0.001, hidden_layer_sizes=(150,), solver=lbfgs; total time=   9.0s
# [CV] END ..alpha=0.01, hidden_layer_sizes=(50,), solver=adam; total time=  11.8s
# [CV] END ..alpha=0.01, hidden_layer_sizes=(50,), solver=adam; total time=  11.9s
# [CV] END ..alpha=0.01, hidden_layer_sizes=(50,), solver=adam; total time=   9.6s
# [CV] END ..alpha=0.01, hidden_layer_sizes=(50,), solver=adam; total time=  11.0s
# /home/omar/Documentos/ESCOM/NLP/ClickbaitDetection/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END .alpha=0.01, hidden_layer_sizes=(50,), solver=lbfgs; total time=  11.0s
# /home/omar/Documentos/ESCOM/NLP/ClickbaitDetection/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END .alpha=0.01, hidden_layer_sizes=(50,), solver=lbfgs; total time=  10.7s
# [CV] END .alpha=0.01, hidden_layer_sizes=(50,), solver=lbfgs; total time=   9.7s
# [CV] END ..alpha=0.01, hidden_layer_sizes=(50,), solver=adam; total time=  12.8s
# /home/omar/Documentos/ESCOM/NLP/ClickbaitDetection/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END .alpha=0.01, hidden_layer_sizes=(50,), solver=lbfgs; total time=  11.1s
# /home/omar/Documentos/ESCOM/NLP/ClickbaitDetection/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END .alpha=0.01, hidden_layer_sizes=(50,), solver=lbfgs; total time=  11.1s
# [CV] END .alpha=0.01, hidden_layer_sizes=(100,), solver=adam; total time=  11.9s
# [CV] END .alpha=0.01, hidden_layer_sizes=(100,), solver=adam; total time=  12.6s
# [CV] END .alpha=0.01, hidden_layer_sizes=(100,), solver=adam; total time=  13.5s
# [CV] END .alpha=0.01, hidden_layer_sizes=(100,), solver=adam; total time=  14.1s
# [CV] END .alpha=0.01, hidden_layer_sizes=(100,), solver=adam; total time=  14.4s
# /home/omar/Documentos/ESCOM/NLP/ClickbaitDetection/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END alpha=0.01, hidden_layer_sizes=(100,), solver=lbfgs; total time=  20.7s
# /home/omar/Documentos/ESCOM/NLP/ClickbaitDetection/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END alpha=0.01, hidden_layer_sizes=(100,), solver=lbfgs; total time=  23.2s
# [CV] END alpha=0.01, hidden_layer_sizes=(100,), solver=lbfgs; total time=  23.8s
# /home/omar/Documentos/ESCOM/NLP/ClickbaitDetection/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END alpha=0.01, hidden_layer_sizes=(100,), solver=lbfgs; total time=  24.5s
# [CV] END alpha=0.01, hidden_layer_sizes=(100, 50), solver=adam; total time=   5.9s
# [CV] END alpha=0.01, hidden_layer_sizes=(100, 50), solver=adam; total time=   5.4s
# /home/omar/Documentos/ESCOM/NLP/ClickbaitDetection/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END alpha=0.01, hidden_layer_sizes=(100,), solver=lbfgs; total time=  21.9s
# [CV] END alpha=0.01, hidden_layer_sizes=(100, 50), solver=adam; total time=   5.1s
# [CV] END alpha=0.01, hidden_layer_sizes=(100, 50), solver=adam; total time=   6.8s
# [CV] END alpha=0.01, hidden_layer_sizes=(100, 50), solver=adam; total time=   7.2s
# [CV] END alpha=0.01, hidden_layer_sizes=(100, 50), solver=lbfgs; total time=  18.1s
# [CV] END alpha=0.01, hidden_layer_sizes=(100, 50), solver=lbfgs; total time=  19.7s
# [CV] END alpha=0.01, hidden_layer_sizes=(100, 50), solver=lbfgs; total time=  28.5s
# [CV] END .alpha=0.01, hidden_layer_sizes=(150,), solver=adam; total time=  17.2s
# [CV] END alpha=0.01, hidden_layer_sizes=(100, 50), solver=lbfgs; total time=  21.2s
# [CV] END alpha=0.01, hidden_layer_sizes=(100, 50), solver=lbfgs; total time=  37.6s
# [CV] END .alpha=0.01, hidden_layer_sizes=(150,), solver=adam; total time=  15.7s
# [CV] END .alpha=0.01, hidden_layer_sizes=(150,), solver=adam; total time=  14.9s
# [CV] END .alpha=0.01, hidden_layer_sizes=(150,), solver=adam; total time=  16.4s
# [CV] END .alpha=0.01, hidden_layer_sizes=(150,), solver=adam; total time=  15.0s
# [CV] END alpha=0.01, hidden_layer_sizes=(150,), solver=lbfgs; total time=  32.1s
# [CV] END alpha=0.01, hidden_layer_sizes=(150,), solver=lbfgs; total time=  36.0s
# /home/omar/Documentos/ESCOM/NLP/ClickbaitDetection/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END alpha=0.01, hidden_layer_sizes=(150,), solver=lbfgs; total time=  38.1s
# /home/omar/Documentos/ESCOM/NLP/ClickbaitDetection/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END alpha=0.01, hidden_layer_sizes=(150,), solver=lbfgs; total time=  35.5s
# /home/omar/Documentos/ESCOM/NLP/ClickbaitDetection/venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV] END alpha=0.01, hidden_layer_sizes=(150,), solver=lbfgs; total time=  22.8s
# Mejor configuración encontrada:
# {'alpha': 0.0001, 'hidden_layer_sizes': (150,), 'solver': 'adam'}
# Mejor F1-macro: 0.7201
#
# Resultados detallados por configuración:
# {'alpha': 0.0001, 'hidden_layer_sizes': (50,), 'solver': 'adam'} -> F1-macro: 0.7056 (+/-0.0185)
# {'alpha': 0.0001, 'hidden_layer_sizes': (50,), 'solver': 'lbfgs'} -> F1-macro: 0.6608 (+/-0.0208)
# {'alpha': 0.0001, 'hidden_layer_sizes': (100,), 'solver': 'adam'} -> F1-macro: 0.7117 (+/-0.0143)
# {'alpha': 0.0001, 'hidden_layer_sizes': (100,), 'solver': 'lbfgs'} -> F1-macro: 0.6660 (+/-0.0202)
# {'alpha': 0.0001, 'hidden_layer_sizes': (100, 50), 'solver': 'adam'} -> F1-macro: 0.7016 (+/-0.0125)
# {'alpha': 0.0001, 'hidden_layer_sizes': (100, 50), 'solver': 'lbfgs'} -> F1-macro: 0.6686 (+/-0.0205)
# {'alpha': 0.0001, 'hidden_layer_sizes': (150,), 'solver': 'adam'} -> F1-macro: 0.7201 (+/-0.0180)
# {'alpha': 0.0001, 'hidden_layer_sizes': (150,), 'solver': 'lbfgs'} -> F1-macro: 0.6711 (+/-0.0123)
# {'alpha': 0.001, 'hidden_layer_sizes': (50,), 'solver': 'adam'} -> F1-macro: 0.7012 (+/-0.0216)
# {'alpha': 0.001, 'hidden_layer_sizes': (50,), 'solver': 'lbfgs'} -> F1-macro: 0.6715 (+/-0.0273)
# {'alpha': 0.001, 'hidden_layer_sizes': (100,), 'solver': 'adam'} -> F1-macro: 0.7054 (+/-0.0133)
# {'alpha': 0.001, 'hidden_layer_sizes': (100,), 'solver': 'lbfgs'} -> F1-macro: 0.6678 (+/-0.0130)
# {'alpha': 0.001, 'hidden_layer_sizes': (100, 50), 'solver': 'adam'} -> F1-macro: 0.7081 (+/-0.0169)
# {'alpha': 0.001, 'hidden_layer_sizes': (100, 50), 'solver': 'lbfgs'} -> F1-macro: 0.6743 (+/-0.0191)
# {'alpha': 0.001, 'hidden_layer_sizes': (150,), 'solver': 'adam'} -> F1-macro: 0.7169 (+/-0.0155)
# {'alpha': 0.001, 'hidden_layer_sizes': (150,), 'solver': 'lbfgs'} -> F1-macro: 0.6573 (+/-0.0228)
# {'alpha': 0.01, 'hidden_layer_sizes': (50,), 'solver': 'adam'} -> F1-macro: 0.7138 (+/-0.0262)
# {'alpha': 0.01, 'hidden_layer_sizes': (50,), 'solver': 'lbfgs'} -> F1-macro: 0.6847 (+/-0.0120)
# {'alpha': 0.01, 'hidden_layer_sizes': (100,), 'solver': 'adam'} -> F1-macro: 0.7042 (+/-0.0104)
# {'alpha': 0.01, 'hidden_layer_sizes': (100,), 'solver': 'lbfgs'} -> F1-macro: 0.6948 (+/-0.0143)
# {'alpha': 0.01, 'hidden_layer_sizes': (100, 50), 'solver': 'adam'} -> F1-macro: 0.7017 (+/-0.0105)
# {'alpha': 0.01, 'hidden_layer_sizes': (100, 50), 'solver': 'lbfgs'} -> F1-macro: 0.6812 (+/-0.0203)
# {'alpha': 0.01, 'hidden_layer_sizes': (150,), 'solver': 'adam'} -> F1-macro: 0.7122 (+/-0.0203)
# {'alpha': 0.01, 'hidden_layer_sizes': (150,), 'solver': 'lbfgs'} -> F1-macro: 0.6961 (+/-0.0262)

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import cross_val_score

# Definir el modelo de MLP
mlp_model = MLPClassifier(hidden_layer_sizes=(150,), max_iter=2000, alpha=0.0001, solver='adam', random_state=0)

# Evaluar el modelo con validación cruzada usando las representaciones reducidas (X_train_reduced)
mlp_scores = cross_val_score(mlp_model, X_train_reduced, train_df['Tag Value'], cv=5, scoring='f1_macro')

# Imprimir los resultados
print("Multi-layer Perceptron (MLPClassifier):")
print(f"F1-macro scores por fold: {mlp_scores}")
print(f"F1-macro promedio: {mlp_scores.mean():.4f}")
# Out:
# Multi-layer Perceptron (MLPClassifier):
# F1-macro scores por fold: [0.73512212 0.6932814  0.71492747 0.69462251 0.68391067]
# F1-macro promedio: 0.7044

# %%
from sklearn.metrics import classification_report, confusion_matrix

# Entrenar el modelo en todo el conjunto de entrenamiento
mlp_model.fit(X_train_reduced, train_df['Tag Value'])

# Predecir sobre el conjunto de validación/desarrollo
y_pred = mlp_model.predict(X_dev_reduced)
y_true = dev_df['Tag Value']

# Imprimir el reporte de clasificación
print("Reporte de clasificación:")
print(classification_report(y_true, y_pred, digits=4))

# Imprimir la matriz de confusión
print("Matriz de confusión:")
print(confusion_matrix(y_true, y_pred))
# Out:
# Reporte de clasificación:
#               precision    recall  f1-score   support
#
#            0     0.8212    0.9000    0.8588       500
#            1     0.6711    0.5100    0.5795       200
#
#     accuracy                         0.7886       700
#    macro avg     0.7461    0.7050    0.7192       700
# weighted avg     0.7783    0.7886    0.7790       700
#
# Matriz de confusión:
# [[450  50]
#  [ 98 102]]

# %% [markdown]
# ## Random forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.metrics import f1_score, make_scorer

# Definir el modelo y los hiperparámetros a probar
rf = RandomForestClassifier(random_state=0)
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# Configurar validación cruzada y búsqueda de hiperparámetros
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)
grid_search = GridSearchCV(
    rf,
    param_grid,
    scoring=make_scorer(f1_score, average='macro'),
    cv=cv,
    n_jobs=-1,
    verbose=2
)

# Ejecutar búsqueda
grid_search.fit(X_train_reduced, train_df['Tag Value'])

# Imprimir mejores resultados
print("Mejor configuración encontrada:")
print(grid_search.best_params_)
print(f"Mejor F1-macro: {grid_search.best_score_:.4f}")

print("\nResultados detallados por configuración:")
means = grid_search.cv_results_['mean_test_score']
stds = grid_search.cv_results_['std_test_score']
params = grid_search.cv_results_['params']
for mean, std, param in zip(means, stds, params):
    print(f"{param} -> F1-macro: {mean:.4f} (+/-{std:.4f})")
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.8s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.9s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   2.0s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.9s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.9s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   3.8s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   3.8s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   3.8s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   3.6s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   2.0s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   4.2s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   2.1s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   2.1s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.9s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   2.0s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   3.8s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   3.8s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   1.0s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   4.0s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   3.9s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   1.0s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   1.0s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   1.0s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   4.1s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   2.0s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   2.0s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   2.0s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   2.0s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   2.0s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   4.1s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   4.0s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   3.9s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   3.9s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   4.1s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.9s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.9s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   2.0s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.9s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.9s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.8s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.8s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.8s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.8s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.9s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.9s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   2.0s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   2.0s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   2.0s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   2.0s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   3.9s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   4.0s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   3.8s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   3.9s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   1.0s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   1.0s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   1.0s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   4.1s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.9s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   2.0s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.9s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   2.0s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   2.0s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   3.8s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   4.1s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   4.0s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   4.1s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   3.8s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.9s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.9s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.8s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.8s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.8s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   3.6s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   3.6s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   3.5s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   3.5s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   3.7s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.8s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.9s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.9s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.8s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.8s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   3.7s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   3.7s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   3.6s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   3.6s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.9s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   3.6s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.8s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.8s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.8s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.8s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.9s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   3.6s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   3.6s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   3.9s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   3.7s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   3.7s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.8s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.7s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.6s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.7s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   1.7s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   3.2s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   3.3s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   3.4s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   3.4s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   3.6s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.9s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.8s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.7s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.7s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.7s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   3.3s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   3.3s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   3.4s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   3.3s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   3.4s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.7s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.7s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.6s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.6s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   1.8s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   3.2s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   3.3s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   3.4s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   3.4s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   3.3s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.7s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.7s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.7s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.7s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.7s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.3s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.2s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.2s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.3s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.4s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.6s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.7s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.7s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.7s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   1.7s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   3.3s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   3.4s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   3.3s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   3.3s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   3.4s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.7s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.6s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.6s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.6s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.6s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   3.3s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   3.3s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   3.3s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   3.3s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   3.6s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.6s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.9s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.7s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.8s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.8s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   3.6s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   3.2s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   3.1s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   3.2s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   3.2s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.6s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.6s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.6s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.7s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.6s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   3.1s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   3.3s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   3.2s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   3.4s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   3.2s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.6s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.7s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.6s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.6s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.6s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   3.3s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   3.1s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   3.1s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   3.2s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   3.2s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   2.1s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   2.3s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   2.1s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   2.1s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   2.1s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   4.3s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   4.3s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   4.3s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   4.1s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   4.5s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   2.2s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   2.1s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   2.1s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   2.2s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   2.4s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   4.3s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   4.5s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   1.0s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   4.4s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   4.3s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   1.1s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   1.0s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   1.1s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   1.1s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   4.2s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   2.1s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   2.1s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   2.1s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   2.1s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   2.1s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   4.2s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   4.2s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   4.1s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   4.1s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.9s
# [CV] END max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   4.3s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.9s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   2.1s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   2.1s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   2.0s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.9s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   4.0s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   4.1s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   3.9s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   4.1s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   2.0s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   2.1s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   2.0s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   2.0s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   2.1s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   4.0s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   4.0s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   1.0s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   4.0s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   3.9s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   1.0s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   1.0s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   1.0s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=50; total time=   1.0s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   4.2s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   2.0s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   2.0s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   2.0s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   2.1s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   2.1s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   4.2s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   4.0s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   4.1s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   4.0s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=50; total time=   0.9s
# [CV] END max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   4.0s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.8s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.9s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.8s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.8s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   1.9s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   3.6s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   3.7s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   3.6s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   3.7s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   3.7s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.8s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.9s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.8s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.8s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.8s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   3.9s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   3.7s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   3.5s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   3.6s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.9s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.9s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.9s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.9s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.9s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   3.9s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.8s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.9s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.8s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.9s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.8s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   3.7s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   3.7s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   3.6s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   3.8s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   3.7s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   2.2s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   2.3s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   2.2s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   2.2s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   2.2s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   4.6s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   4.4s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   4.5s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   4.2s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   1.2s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   1.3s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   1.2s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   2.1s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   4.7s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   2.2s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   2.3s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   2.2s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   2.3s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   4.1s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   4.6s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   1.1s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   4.2s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   4.4s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   1.2s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   1.0s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   1.1s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=50; total time=   1.1s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   4.5s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   2.2s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   2.3s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   2.3s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   2.2s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   2.2s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   4.3s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   4.4s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   4.3s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   4.4s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   1.0s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=50; total time=   1.1s
# [CV] END max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   4.5s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   2.1s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   2.1s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   1.9s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   2.1s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   2.2s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   4.0s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   4.1s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   4.0s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   4.2s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   1.1s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   4.1s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   2.0s
# [CV] END max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   2.0s
# ...
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   0.9s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=50; total time=   1.0s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   3.7s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.9s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.9s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.8s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.9s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   1.8s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   3.8s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   3.8s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   3.6s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   3.6s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.9s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.9s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.9s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.9s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=50; total time=   0.9s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   3.7s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.9s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.8s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.9s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.9s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   2.0s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   3.9s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   3.8s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   3.8s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   3.5s
# [CV] END max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   3.2s
# Mejor configuración encontrada:
# {'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 100}
# Mejor F1-macro: 0.6558
#
# Resultados detallados por configuración:
# {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50} -> F1-macro: 0.6485 (+/-0.0157)
# {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100} -> F1-macro: 0.6449 (+/-0.0135)
# {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200} -> F1-macro: 0.6460 (+/-0.0089)
# {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 50} -> F1-macro: 0.6518 (+/-0.0132)
# {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100} -> F1-macro: 0.6527 (+/-0.0069)
# {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200} -> F1-macro: 0.6519 (+/-0.0123)
# {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 50} -> F1-macro: 0.6486 (+/-0.0199)
# {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 100} -> F1-macro: 0.6553 (+/-0.0075)
# {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 200} -> F1-macro: 0.6491 (+/-0.0175)
# {'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 50} -> F1-macro: 0.6468 (+/-0.0100)
# {'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100} -> F1-macro: 0.6518 (+/-0.0140)
# {'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 200} -> F1-macro: 0.6391 (+/-0.0199)
# {'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 50} -> F1-macro: 0.6489 (+/-0.0138)
# {'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100} -> F1-macro: 0.6521 (+/-0.0084)
# {'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 200} -> F1-macro: 0.6434 (+/-0.0091)
# {'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 50} -> F1-macro: 0.6403 (+/-0.0223)
# {'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 100} -> F1-macro: 0.6338 (+/-0.0117)
# {'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 200} -> F1-macro: 0.6434 (+/-0.0096)
# {'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 50} -> F1-macro: 0.6351 (+/-0.0187)
# {'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 100} -> F1-macro: 0.6309 (+/-0.0107)
# {'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 200} -> F1-macro: 0.6359 (+/-0.0122)
# {'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 50} -> F1-macro: 0.6351 (+/-0.0187)
# {'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 100} -> F1-macro: 0.6309 (+/-0.0107)
# {'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 200} -> F1-macro: 0.6359 (+/-0.0122)
# {'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 50} -> F1-macro: 0.6407 (+/-0.0149)
# {'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 100} -> F1-macro: 0.6366 (+/-0.0132)
# {'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 200} -> F1-macro: 0.6314 (+/-0.0155)
# {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50} -> F1-macro: 0.6232 (+/-0.0206)
# {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100} -> F1-macro: 0.6237 (+/-0.0163)
# {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200} -> F1-macro: 0.6248 (+/-0.0140)
# {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 50} -> F1-macro: 0.6259 (+/-0.0087)
# {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100} -> F1-macro: 0.6311 (+/-0.0123)
# {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200} -> F1-macro: 0.6250 (+/-0.0178)
# {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 50} -> F1-macro: 0.6272 (+/-0.0166)
# {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 100} -> F1-macro: 0.6331 (+/-0.0126)
# {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 200} -> F1-macro: 0.6279 (+/-0.0132)
# {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 50} -> F1-macro: 0.6354 (+/-0.0096)
# {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100} -> F1-macro: 0.6298 (+/-0.0162)
# {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 200} -> F1-macro: 0.6291 (+/-0.0125)
# {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 50} -> F1-macro: 0.6248 (+/-0.0196)
# {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100} -> F1-macro: 0.6187 (+/-0.0178)
# {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 200} -> F1-macro: 0.6177 (+/-0.0183)
# {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 50} -> F1-macro: 0.6231 (+/-0.0197)
# {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 100} -> F1-macro: 0.6259 (+/-0.0165)
# {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 200} -> F1-macro: 0.6220 (+/-0.0120)
# {'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 50} -> F1-macro: 0.6402 (+/-0.0191)
# {'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 100} -> F1-macro: 0.6252 (+/-0.0144)
# {'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 200} -> F1-macro: 0.6216 (+/-0.0118)
# {'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 50} -> F1-macro: 0.6402 (+/-0.0191)
# {'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 100} -> F1-macro: 0.6252 (+/-0.0144)
# {'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 200} -> F1-macro: 0.6216 (+/-0.0118)
# {'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 50} -> F1-macro: 0.6351 (+/-0.0157)
# {'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 100} -> F1-macro: 0.6218 (+/-0.0102)
# {'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 200} -> F1-macro: 0.6213 (+/-0.0135)
# {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50} -> F1-macro: 0.6438 (+/-0.0116)
# {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100} -> F1-macro: 0.6472 (+/-0.0161)
# {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200} -> F1-macro: 0.6459 (+/-0.0148)
# {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 50} -> F1-macro: 0.6512 (+/-0.0174)
# {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100} -> F1-macro: 0.6490 (+/-0.0150)
# {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200} -> F1-macro: 0.6486 (+/-0.0182)
# {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 50} -> F1-macro: 0.6445 (+/-0.0231)
# {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 100} -> F1-macro: 0.6419 (+/-0.0158)
# {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 200} -> F1-macro: 0.6470 (+/-0.0093)
# {'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 50} -> F1-macro: 0.6421 (+/-0.0167)
# {'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100} -> F1-macro: 0.6482 (+/-0.0134)
# {'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 200} -> F1-macro: 0.6402 (+/-0.0145)
# {'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 50} -> F1-macro: 0.6453 (+/-0.0079)
# {'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100} -> F1-macro: 0.6534 (+/-0.0134)
# {'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 200} -> F1-macro: 0.6456 (+/-0.0106)
# {'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 50} -> F1-macro: 0.6434 (+/-0.0198)
# {'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 100} -> F1-macro: 0.6356 (+/-0.0091)
# {'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 200} -> F1-macro: 0.6381 (+/-0.0056)
# {'max_depth': 20, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 50} -> F1-macro: 0.6374 (+/-0.0166)
# {'max_depth': 20, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 100} -> F1-macro: 0.6320 (+/-0.0129)
# {'max_depth': 20, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 200} -> F1-macro: 0.6335 (+/-0.0118)
# {'max_depth': 20, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 50} -> F1-macro: 0.6374 (+/-0.0166)
# {'max_depth': 20, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 100} -> F1-macro: 0.6320 (+/-0.0129)
# {'max_depth': 20, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 200} -> F1-macro: 0.6335 (+/-0.0118)
# {'max_depth': 20, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 50} -> F1-macro: 0.6403 (+/-0.0144)
# {'max_depth': 20, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 100} -> F1-macro: 0.6338 (+/-0.0123)
# {'max_depth': 20, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 200} -> F1-macro: 0.6326 (+/-0.0148)
# {'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50} -> F1-macro: 0.6494 (+/-0.0204)
# {'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100} -> F1-macro: 0.6483 (+/-0.0170)
# {'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200} -> F1-macro: 0.6460 (+/-0.0091)
# {'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 50} -> F1-macro: 0.6521 (+/-0.0133)
# {'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100} -> F1-macro: 0.6538 (+/-0.0076)
# {'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200} -> F1-macro: 0.6525 (+/-0.0131)
# {'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 50} -> F1-macro: 0.6444 (+/-0.0131)
# {'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 100} -> F1-macro: 0.6558 (+/-0.0076)
# {'max_depth': 30, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 200} -> F1-macro: 0.6480 (+/-0.0168)
# {'max_depth': 30, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 50} -> F1-macro: 0.6468 (+/-0.0100)
# {'max_depth': 30, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100} -> F1-macro: 0.6518 (+/-0.0140)
# {'max_depth': 30, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 200} -> F1-macro: 0.6391 (+/-0.0199)
# {'max_depth': 30, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 50} -> F1-macro: 0.6489 (+/-0.0138)
# {'max_depth': 30, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100} -> F1-macro: 0.6521 (+/-0.0084)
# {'max_depth': 30, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 200} -> F1-macro: 0.6434 (+/-0.0091)
# {'max_depth': 30, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 50} -> F1-macro: 0.6403 (+/-0.0223)
# {'max_depth': 30, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 100} -> F1-macro: 0.6338 (+/-0.0117)
# {'max_depth': 30, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 200} -> F1-macro: 0.6434 (+/-0.0096)
# {'max_depth': 30, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 50} -> F1-macro: 0.6351 (+/-0.0187)
# {'max_depth': 30, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 100} -> F1-macro: 0.6309 (+/-0.0107)
# {'max_depth': 30, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 200} -> F1-macro: 0.6359 (+/-0.0122)
# {'max_depth': 30, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 50} -> F1-macro: 0.6351 (+/-0.0187)
# {'max_depth': 30, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 100} -> F1-macro: 0.6309 (+/-0.0107)
# {'max_depth': 30, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 200} -> F1-macro: 0.6359 (+/-0.0122)
# {'max_depth': 30, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 50} -> F1-macro: 0.6407 (+/-0.0149)
# {'max_depth': 30, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 100} -> F1-macro: 0.6366 (+/-0.0132)
# {'max_depth': 30, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 200} -> F1-macro: 0.6314 (+/-0.0155)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

# Definir el modelo de Random Forest
rf_model = RandomForestClassifier(max_depth=30, min_samples_leaf=1, min_samples_split=10,n_estimators=100, random_state=0)

# Evaluar el modelo con validación cruzada usando las representaciones reducidas (X_train_reduced)
rf_scores = cross_val_score(rf_model, X_train_reduced, train_df['Tag Value'], cv=5, scoring='f1_macro')

# Imprimir los resultados
print("Random Forest:")
print(f"F1-macro scores por fold: {rf_scores}")
print(f"F1-macro promedio: {rf_scores.mean():.4f}")
# Out:
# Random Forest:
# F1-macro scores por fold: [0.64603855 0.6124671  0.66253844 0.63211679 0.66029412]
# F1-macro promedio: 0.6427

# %%
from sklearn.metrics import classification_report, confusion_matrix

# Entrenar el modelo en todo el conjunto de entrenamiento
rf_model.fit(X_train_reduced, train_df['Tag Value'])

# Predecir sobre el conjunto de validación/desarrollo
y_pred = rf_model.predict(X_dev_reduced)
y_true = dev_df['Tag Value']

# Imprimir el reporte de clasificación
print("Reporte de clasificación:")
print(classification_report(y_true, y_pred, digits=4))

# Imprimir la matriz de confusión
print("Matriz de confusión:")
print(confusion_matrix(y_true, y_pred))
# Out:
# Reporte de clasificación:
#               precision    recall  f1-score   support
#
#            0     0.7778    0.9800    0.8673       500
#            1     0.8571    0.3000    0.4444       200
#
#     accuracy                         0.7857       700
#    macro avg     0.8175    0.6400    0.6559       700
# weighted avg     0.8005    0.7857    0.7465       700
#
# Matriz de confusión:
# [[490  10]
#  [140  60]]

# %% [markdown]
# ## Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.metrics import f1_score, make_scorer

# Definir el modelo y los hiperparámetros a probar
gb = GradientBoostingClassifier(random_state=0)
param_grid = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.01, 0.05, 0.1],
    'max_depth': [2, 3, 5],
    'subsample': [0.8, 1.0]
}

# Configurar validación cruzada y búsqueda de hiperparámetros
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)
grid_search = GridSearchCV(
    gb,
    param_grid,
    scoring=make_scorer(f1_score, average='macro'),
    cv=cv,
    n_jobs=-1,
    verbose=2
)

# Ejecutar búsqueda
grid_search.fit(X_train_reduced, train_df['Tag Value'])

# Imprimir mejores resultados
print("Mejor configuración encontrada:")
print(grid_search.best_params_)
print(f"Mejor F1-macro: {grid_search.best_score_:.4f}")

print("\nResultados detallados por configuración:")
means = grid_search.cv_results_['mean_test_score']
stds = grid_search.cv_results_['std_test_score']
params = grid_search.cv_results_['params']
for mean, std, param in zip(means, stds, params):
    print(f"{param} -> F1-macro: {mean:.4f} (+/-{std:.4f})")
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.8; total time=   1.9s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.8; total time=   1.9s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.8; total time=   2.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.8; total time=   2.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=0.8; total time=   1.9s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=1.0; total time=   2.3s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=1.0; total time=   2.4s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=1.0; total time=   2.5s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=1.0; total time=   2.4s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=50, subsample=1.0; total time=   2.4s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.8; total time=   3.8s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.8; total time=   4.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.8; total time=   4.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.8; total time=   4.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=0.8; total time=   3.9s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=1.0; total time=   4.9s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=1.0; total time=   5.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=1.0; total time=   4.9s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=1.0; total time=   5.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=100, subsample=1.0; total time=   4.9s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.8; total time=   7.7s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.8; total time=   7.9s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.8; total time=   8.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.8; total time=   8.2s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=0.8; total time=   8.0s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=1.0; total time=  10.2s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=1.0; total time=  10.4s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=1.0; total time=  10.4s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.8; total time=   3.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.8; total time=   3.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=1.0; total time=  10.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.8; total time=   3.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.8; total time=   3.1s
# [CV] END learning_rate=0.01, max_depth=2, n_estimators=200, subsample=1.0; total time=  10.5s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=0.8; total time=   3.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=1.0; total time=   3.9s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=1.0; total time=   3.8s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=1.0; total time=   3.9s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=1.0; total time=   3.8s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=50, subsample=1.0; total time=   3.8s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8; total time=   6.4s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8; total time=   6.1s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8; total time=   6.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8; total time=   6.4s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=0.8; total time=   6.3s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1.0; total time=   7.8s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1.0; total time=   7.8s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1.0; total time=   7.8s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1.0; total time=   8.0s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1.0; total time=   7.8s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.8; total time=  12.3s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.8; total time=  12.3s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.8; total time=  12.5s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.8; total time=  12.6s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=0.8; total time=  12.8s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=1.0; total time=  15.3s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=1.0; total time=  15.6s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=1.0; total time=  15.7s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.8; total time=   5.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.8; total time=   5.3s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=1.0; total time=  16.5s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.8; total time=   5.4s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=200, subsample=1.0; total time=  15.7s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.8; total time=   5.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.8; total time=   5.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=1.0; total time=   6.8s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=1.0; total time=   6.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=1.0; total time=   6.3s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=1.0; total time=   6.4s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=50, subsample=1.0; total time=   6.5s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.8; total time=  10.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.8; total time=  10.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.8; total time=  10.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.8; total time=  10.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.8; total time=  10.4s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=1.0; total time=  13.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=1.0; total time=  12.6s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=1.0; total time=  12.7s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=1.0; total time=  12.5s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, subsample=1.0; total time=  13.4s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.8; total time=  19.9s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.8; total time=  20.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.8; total time=  20.5s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.8; total time=  20.8s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.8; total time=  20.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=1.0; total time=  26.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=1.0; total time=  25.9s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=50, subsample=0.8; total time=   2.2s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=50, subsample=0.8; total time=   2.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=1.0; total time=  26.0s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=50, subsample=0.8; total time=   2.4s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=50, subsample=0.8; total time=   2.3s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=50, subsample=0.8; total time=   2.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=1.0; total time=  25.2s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=50, subsample=1.0; total time=   2.8s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=50, subsample=1.0; total time=   2.8s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=50, subsample=1.0; total time=   2.7s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=50, subsample=1.0; total time=   2.8s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=50, subsample=1.0; total time=   2.8s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=100, subsample=0.8; total time=   4.2s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=100, subsample=0.8; total time=   4.6s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=100, subsample=0.8; total time=   4.4s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=100, subsample=0.8; total time=   4.3s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=100, subsample=0.8; total time=   4.4s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=200, subsample=1.0; total time=  26.0s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=100, subsample=1.0; total time=   5.7s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=100, subsample=1.0; total time=   5.5s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=100, subsample=1.0; total time=   5.4s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=100, subsample=1.0; total time=   5.6s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=100, subsample=1.0; total time=   5.5s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=200, subsample=0.8; total time=   8.7s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=200, subsample=0.8; total time=   8.6s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=200, subsample=0.8; total time=   8.9s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=200, subsample=0.8; total time=   8.6s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=200, subsample=0.8; total time=   8.9s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=200, subsample=1.0; total time=  10.9s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=200, subsample=1.0; total time=  10.7s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=200, subsample=1.0; total time=  10.7s
# [CV] END learning_rate=0.05, max_depth=3, n_estimators=50, subsample=0.8; total time=   3.3s
# [CV] END learning_rate=0.05, max_depth=3, n_estimators=50, subsample=0.8; total time=   3.1s
# [CV] END learning_rate=0.05, max_depth=3, n_estimators=50, subsample=0.8; total time=   3.1s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=200, subsample=1.0; total time=  11.0s
# [CV] END learning_rate=0.05, max_depth=3, n_estimators=50, subsample=0.8; total time=   3.1s
# [CV] END learning_rate=0.05, max_depth=3, n_estimators=50, subsample=0.8; total time=   3.1s
# [CV] END learning_rate=0.05, max_depth=2, n_estimators=200, subsample=1.0; total time=  11.3s
# [CV] END learning_rate=0.05, max_depth=3, n_estimators=50, subsample=1.0; total time=   4.1s
# [CV] END learning_rate=0.05, max_depth=3, n_estimators=50, subsample=1.0; total time=   4.1s
# [CV] END learning_rate=0.05, max_depth=3, n_estimators=50, subsample=1.0; total time=   3.9s
# [CV] END learning_rate=0.05, max_depth=3, n_estimators=50, subsample=1.0; total time=   4.0s
# [CV] END learning_rate=0.05, max_depth=3, n_estimators=50, subsample=1.0; total time=   4.0s
# [CV] END learning_rate=0.05, max_depth=3, n_estimators=100, subsample=0.8; total time=   6.3s
# [CV] END learning_rate=0.05, max_depth=3, n_estimators=100, subsample=0.8; total time=   6.1s
# [CV] END learning_rate=0.05, max_depth=3, n_estimators=100, subsample=0.8; total time=   6.5s
# [CV] END learning_rate=0.05, max_depth=3, n_estimators=100, subsample=0.8; total time=   6.3s
# [CV] END learning_rate=0.05, max_depth=3, n_estimators=100, subsample=0.8; total time=   6.4s
# [CV] END learning_rate=0.05, max_depth=3, n_estimators=100, subsample=1.0; total time=   7.9s
# [CV] END learning_rate=0.05, max_depth=3, n_estimators=100, subsample=1.0; total time=   7.9s
# [CV] END learning_rate=0.05, max_depth=3, n_estimators=100, subsample=1.0; total time=   7.9s
# [CV] END learning_rate=0.05, max_depth=3, n_estimators=100, subsample=1.0; total time=   8.1s
# [CV] END learning_rate=0.05, max_depth=3, n_estimators=100, subsample=1.0; total time=   7.9s
# [CV] END learning_rate=0.05, max_depth=3, n_estimators=200, subsample=0.8; total time=  12.6s
# [CV] END learning_rate=0.05, max_depth=3, n_estimators=200, subsample=0.8; total time=  12.7s
# [CV] END learning_rate=0.05, max_depth=3, n_estimators=200, subsample=0.8; total time=  12.6s
# [CV] END learning_rate=0.05, max_depth=3, n_estimators=200, subsample=0.8; total time=  13.1s
# [CV] END learning_rate=0.05, max_depth=3, n_estimators=200, subsample=0.8; total time=  12.9s
# [CV] END learning_rate=0.05, max_depth=3, n_estimators=200, subsample=1.0; total time=  16.1s
# [CV] END learning_rate=0.05, max_depth=3, n_estimators=200, subsample=1.0; total time=  16.1s
# [CV] END learning_rate=0.05, max_depth=3, n_estimators=200, subsample=1.0; total time=  15.9s
# [CV] END learning_rate=0.05, max_depth=5, n_estimators=50, subsample=0.8; total time=   5.3s
# [CV] END learning_rate=0.05, max_depth=5, n_estimators=50, subsample=0.8; total time=   5.1s
# [CV] END learning_rate=0.05, max_depth=3, n_estimators=200, subsample=1.0; total time=  15.9s
# [CV] END learning_rate=0.05, max_depth=5, n_estimators=50, subsample=0.8; total time=   5.1s
# [CV] END learning_rate=0.05, max_depth=5, n_estimators=50, subsample=0.8; total time=   5.0s
# [CV] END learning_rate=0.05, max_depth=3, n_estimators=200, subsample=1.0; total time=  16.0s
# [CV] END learning_rate=0.05, max_depth=5, n_estimators=50, subsample=0.8; total time=   5.3s
# [CV] END learning_rate=0.05, max_depth=5, n_estimators=50, subsample=1.0; total time=   6.4s
# [CV] END learning_rate=0.05, max_depth=5, n_estimators=50, subsample=1.0; total time=   6.5s
# [CV] END learning_rate=0.05, max_depth=5, n_estimators=50, subsample=1.0; total time=   6.3s
# [CV] END learning_rate=0.05, max_depth=5, n_estimators=50, subsample=1.0; total time=   6.5s
# [CV] END learning_rate=0.05, max_depth=5, n_estimators=50, subsample=1.0; total time=   6.6s
# [CV] END learning_rate=0.05, max_depth=5, n_estimators=100, subsample=0.8; total time=  10.2s
# [CV] END learning_rate=0.05, max_depth=5, n_estimators=100, subsample=0.8; total time=  10.2s
# [CV] END learning_rate=0.05, max_depth=5, n_estimators=100, subsample=0.8; total time=  10.3s
# [CV] END learning_rate=0.05, max_depth=5, n_estimators=100, subsample=0.8; total time=  10.6s
# [CV] END learning_rate=0.05, max_depth=5, n_estimators=100, subsample=0.8; total time=  10.2s
# [CV] END learning_rate=0.05, max_depth=5, n_estimators=100, subsample=1.0; total time=  13.2s
# [CV] END learning_rate=0.05, max_depth=5, n_estimators=100, subsample=1.0; total time=  13.4s
# [CV] END learning_rate=0.05, max_depth=5, n_estimators=100, subsample=1.0; total time=  13.0s
# [CV] END learning_rate=0.05, max_depth=5, n_estimators=100, subsample=1.0; total time=  12.9s
# [CV] END learning_rate=0.05, max_depth=5, n_estimators=100, subsample=1.0; total time=  12.9s
# [CV] END learning_rate=0.05, max_depth=5, n_estimators=200, subsample=0.8; total time=  21.0s
# [CV] END learning_rate=0.05, max_depth=5, n_estimators=200, subsample=0.8; total time=  21.0s
# [CV] END learning_rate=0.05, max_depth=5, n_estimators=200, subsample=0.8; total time=  20.7s
# [CV] END learning_rate=0.05, max_depth=5, n_estimators=200, subsample=0.8; total time=  20.2s
# [CV] END learning_rate=0.05, max_depth=5, n_estimators=200, subsample=0.8; total time=  20.6s
# [CV] END learning_rate=0.05, max_depth=5, n_estimators=200, subsample=1.0; total time=  27.1s
# [CV] END learning_rate=0.05, max_depth=5, n_estimators=200, subsample=1.0; total time=  26.2s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=50, subsample=0.8; total time=   2.2s
# [CV] END learning_rate=0.05, max_depth=5, n_estimators=200, subsample=1.0; total time=  26.0s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=50, subsample=0.8; total time=   2.2s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=50, subsample=0.8; total time=   2.1s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=50, subsample=0.8; total time=   2.2s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=50, subsample=0.8; total time=   2.1s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=50, subsample=1.0; total time=   2.7s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=50, subsample=1.0; total time=   2.7s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=50, subsample=1.0; total time=   2.8s
# [CV] END learning_rate=0.05, max_depth=5, n_estimators=200, subsample=1.0; total time=  26.0s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=50, subsample=1.0; total time=   2.7s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=50, subsample=1.0; total time=   2.7s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=100, subsample=0.8; total time=   4.4s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=100, subsample=0.8; total time=   4.4s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=100, subsample=0.8; total time=   4.4s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=100, subsample=0.8; total time=   4.3s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=100, subsample=0.8; total time=   4.6s
# [CV] END learning_rate=0.05, max_depth=5, n_estimators=200, subsample=1.0; total time=  26.2s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=100, subsample=1.0; total time=   5.5s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=100, subsample=1.0; total time=   5.4s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=100, subsample=1.0; total time=   5.6s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=100, subsample=1.0; total time=   5.5s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=100, subsample=1.0; total time=   5.8s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=200, subsample=0.8; total time=   8.5s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=200, subsample=0.8; total time=   8.7s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=200, subsample=0.8; total time=   8.9s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=200, subsample=0.8; total time=   9.1s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=200, subsample=0.8; total time=   8.7s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=200, subsample=1.0; total time=  11.2s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=200, subsample=1.0; total time=  11.0s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.8; total time=   3.1s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=200, subsample=1.0; total time=  11.2s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.8; total time=   3.2s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.8; total time=   3.2s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=200, subsample=1.0; total time=  11.0s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.8; total time=   3.2s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=50, subsample=0.8; total time=   3.2s
# [CV] END learning_rate=0.1, max_depth=2, n_estimators=200, subsample=1.0; total time=  11.3s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=50, subsample=1.0; total time=   4.1s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=50, subsample=1.0; total time=   4.0s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=50, subsample=1.0; total time=   4.0s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=50, subsample=1.0; total time=   4.1s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=50, subsample=1.0; total time=   4.2s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.8; total time=   6.5s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.8; total time=   6.7s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.8; total time=   6.6s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.8; total time=   7.0s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.8; total time=   6.5s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1.0; total time=   8.2s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1.0; total time=   8.5s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1.0; total time=   8.4s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1.0; total time=   8.1s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1.0; total time=   8.2s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.8; total time=  13.0s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.8; total time=  13.0s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.8; total time=  12.7s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.8; total time=  13.1s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.8; total time=  12.9s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=1.0; total time=  16.9s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=1.0; total time=  16.6s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=1.0; total time=  16.3s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.8; total time=   5.2s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.8; total time=   5.3s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=1.0; total time=  16.3s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.8; total time=   5.1s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.8; total time=   5.3s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=50, subsample=0.8; total time=   5.1s
# [CV] END learning_rate=0.1, max_depth=3, n_estimators=200, subsample=1.0; total time=  16.6s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=50, subsample=1.0; total time=   6.8s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=50, subsample=1.0; total time=   6.7s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=50, subsample=1.0; total time=   6.3s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=50, subsample=1.0; total time=   6.5s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=50, subsample=1.0; total time=   6.4s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.8; total time=  10.0s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.8; total time=  10.4s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.8; total time=  10.3s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.8; total time=  10.2s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=0.8; total time=  10.1s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=1.0; total time=  13.5s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=1.0; total time=  13.2s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=1.0; total time=  12.9s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=1.0; total time=  13.0s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=100, subsample=1.0; total time=  13.2s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.8; total time=  20.3s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.8; total time=  20.8s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.8; total time=  20.6s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.8; total time=  20.2s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=0.8; total time=  20.8s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=1.0; total time=  26.3s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=1.0; total time=  26.2s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=1.0; total time=  25.5s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=1.0; total time=  24.8s
# [CV] END learning_rate=0.1, max_depth=5, n_estimators=200, subsample=1.0; total time=  23.0s
# Mejor configuración encontrada:
# {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 200, 'subsample': 0.8}
# Mejor F1-macro: 0.6946
#
# Resultados detallados por configuración:
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 50, 'subsample': 0.8} -> F1-macro: 0.4479 (+/-0.0132)
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 50, 'subsample': 1.0} -> F1-macro: 0.4448 (+/-0.0110)
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 100, 'subsample': 0.8} -> F1-macro: 0.5309 (+/-0.0272)
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 100, 'subsample': 1.0} -> F1-macro: 0.5317 (+/-0.0125)
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 200, 'subsample': 0.8} -> F1-macro: 0.6061 (+/-0.0121)
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 200, 'subsample': 1.0} -> F1-macro: 0.5956 (+/-0.0179)
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.8} -> F1-macro: 0.4882 (+/-0.0207)
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50, 'subsample': 1.0} -> F1-macro: 0.4905 (+/-0.0224)
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.8} -> F1-macro: 0.5801 (+/-0.0129)
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'subsample': 1.0} -> F1-macro: 0.5812 (+/-0.0077)
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200, 'subsample': 0.8} -> F1-macro: 0.6259 (+/-0.0145)
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200, 'subsample': 1.0} -> F1-macro: 0.6263 (+/-0.0070)
# {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50, 'subsample': 0.8} -> F1-macro: 0.5169 (+/-0.0146)
# {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 50, 'subsample': 1.0} -> F1-macro: 0.5408 (+/-0.0096)
# {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100, 'subsample': 0.8} -> F1-macro: 0.5948 (+/-0.0190)
# {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100, 'subsample': 1.0} -> F1-macro: 0.6145 (+/-0.0260)
# {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 200, 'subsample': 0.8} -> F1-macro: 0.6384 (+/-0.0186)
# {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 200, 'subsample': 1.0} -> F1-macro: 0.6403 (+/-0.0104)
# {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 50, 'subsample': 0.8} -> F1-macro: 0.6224 (+/-0.0111)
# {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 50, 'subsample': 1.0} -> F1-macro: 0.6127 (+/-0.0102)
# {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 100, 'subsample': 0.8} -> F1-macro: 0.6520 (+/-0.0131)
# {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 100, 'subsample': 1.0} -> F1-macro: 0.6402 (+/-0.0177)
# {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 200, 'subsample': 0.8} -> F1-macro: 0.6745 (+/-0.0190)
# {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 200, 'subsample': 1.0} -> F1-macro: 0.6577 (+/-0.0122)
# {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.8} -> F1-macro: 0.6452 (+/-0.0167)
# {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50, 'subsample': 1.0} -> F1-macro: 0.6409 (+/-0.0151)
# {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.8} -> F1-macro: 0.6714 (+/-0.0126)
# {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100, 'subsample': 1.0} -> F1-macro: 0.6620 (+/-0.0220)
# {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 200, 'subsample': 0.8} -> F1-macro: 0.6848 (+/-0.0181)
# {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 200, 'subsample': 1.0} -> F1-macro: 0.6825 (+/-0.0232)
# {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 50, 'subsample': 0.8} -> F1-macro: 0.6563 (+/-0.0240)
# {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 50, 'subsample': 1.0} -> F1-macro: 0.6536 (+/-0.0235)
# {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 100, 'subsample': 0.8} -> F1-macro: 0.6908 (+/-0.0274)
# {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 100, 'subsample': 1.0} -> F1-macro: 0.6683 (+/-0.0157)
# {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 200, 'subsample': 0.8} -> F1-macro: 0.6946 (+/-0.0284)
# {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 200, 'subsample': 1.0} -> F1-macro: 0.6857 (+/-0.0157)
# {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 50, 'subsample': 0.8} -> F1-macro: 0.6457 (+/-0.0171)
# {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 50, 'subsample': 1.0} -> F1-macro: 0.6438 (+/-0.0146)
# {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100, 'subsample': 0.8} -> F1-macro: 0.6718 (+/-0.0139)
# {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100, 'subsample': 1.0} -> F1-macro: 0.6642 (+/-0.0106)
# {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 200, 'subsample': 0.8} -> F1-macro: 0.6928 (+/-0.0207)
# {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 200, 'subsample': 1.0} -> F1-macro: 0.6900 (+/-0.0125)
# {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.8} -> F1-macro: 0.6708 (+/-0.0316)
# {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50, 'subsample': 1.0} -> F1-macro: 0.6583 (+/-0.0188)
# {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.8} -> F1-macro: 0.6828 (+/-0.0228)
# {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'subsample': 1.0} -> F1-macro: 0.6760 (+/-0.0190)
# {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 200, 'subsample': 0.8} -> F1-macro: 0.6842 (+/-0.0255)
# {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 200, 'subsample': 1.0} -> F1-macro: 0.6819 (+/-0.0185)
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50, 'subsample': 0.8} -> F1-macro: 0.6704 (+/-0.0323)
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50, 'subsample': 1.0} -> F1-macro: 0.6779 (+/-0.0186)
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'subsample': 0.8} -> F1-macro: 0.6807 (+/-0.0196)
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'subsample': 1.0} -> F1-macro: 0.6800 (+/-0.0213)
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200, 'subsample': 0.8} -> F1-macro: 0.6883 (+/-0.0282)
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200, 'subsample': 1.0} -> F1-macro: 0.6877 (+/-0.0252)

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import cross_val_score

# Definir el modelo de Gradient Boosting
gb_model = GradientBoostingClassifier(subsample=0.8,n_estimators=200, learning_rate=0.05, max_depth=5, random_state=0)

# Evaluar el modelo con validación cruzada usando las representaciones reducidas (X_train_reduced)
gb_scores = cross_val_score(gb_model, X_train_reduced, train_df['Tag Value'], cv=5, scoring='f1_macro')

# Imprimir los resultados
print("Gradient Boosting:")
print(f"F1-macro scores por fold: {gb_scores}")
print(f"F1-macro promedio: {gb_scores.mean():.4f}")
# Out:
# Gradient Boosting:
# F1-macro scores por fold: [0.70772939 0.67381174 0.72424242 0.69827331 0.7030303 ]
# F1-macro promedio: 0.7014

# %%
from sklearn.metrics import classification_report, confusion_matrix

# Entrenar el modelo en todo el conjunto de entrenamiento
gb_model.fit(X_train_reduced, train_df['Tag Value'])

# Predecir sobre el conjunto de validación/desarrollo
y_pred = gb_model.predict(X_dev_reduced)
y_true = dev_df['Tag Value']

# Imprimir el reporte de clasificación
print("Reporte de clasificación:")
print(classification_report(y_true, y_pred, digits=4))

# Imprimir la matriz de confusión
print("Matriz de confusión:")
print(confusion_matrix(y_true, y_pred))
# Out:
# Reporte de clasificación:
#               precision    recall  f1-score   support
#
#            0     0.7859    0.9620    0.8651       500
#            1     0.7841    0.3450    0.4792       200
#
#     accuracy                         0.7857       700
#    macro avg     0.7850    0.6535    0.6721       700
# weighted avg     0.7854    0.7857    0.7548       700
#
# Matriz de confusión:
# [[481  19]
#  [131  69]]
